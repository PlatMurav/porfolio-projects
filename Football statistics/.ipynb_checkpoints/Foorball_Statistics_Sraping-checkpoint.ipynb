# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
standings_url = 'https://fbref.com/en/comps/9/Premier-League-Stats'

# %%
data = requests.get(standings_url)

# %%
data #just checking what type of object "data" is
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(data.text)

# %%
soup.select('table.stats_table')
# Out:
# [<table class="stats_table sortable min_width" data-cols-to-freeze=",1" id="stats_standard_9"> <caption>Standard Stats <span style="color: #666; font-size:smaller">2021-2022 Norwich City: Premier League</span> Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr class="over_header"> <th aria-label="" class="over_header center" colspan="4" data-stat=""></th><th></th> <th aria-label="" class="over_header center group_start" colspan="3" data-stat="header_playing">Playing Time</th> <th aria-label="" class="over_header center group_start" colspan="8" data-stat="header_performance">Performance</th> <th aria-label="" class="over_header center group_start" colspan="4" data-stat="header_expected">Expected</th> <th aria-label="" class="over_header center group_start" colspan="3" data-stat="header_progression">Progression</th> <th aria-label="" class="over_header center group_start" colspan="10" data-stat="header_per90">Per 90 Minutes</th><th></th> </tr> <tr> <th aria-label="Player" class="poptip sort_default_asc left" data-stat="player" scope="col">Player</th> <th aria-label="Nation" class="poptip sort_default_asc center" data-stat="nationality" data-tip="Nationality of the player.&lt;br&gt;First, we check our records in international play at senior level.&lt;br&gt;Then youth level.&lt;br&gt;Then citizenship presented on wikipedia.&lt;br&gt;Finally, we use their birthplace when available." scope="col">Nation</th> <th aria-label="Position" class="poptip center" data-stat="position" data-tip="&lt;strong&gt;Position&lt;/strong&gt;&lt;br&gt;Position most commonly played by the player&lt;br&gt;GK - Goalkeepers&lt;br&gt;DF - Defenders&lt;br&gt;MF - Midfielders&lt;br&gt;FW - Forwards&lt;br&gt;FB - Fullbacks&lt;br&gt;LB - Left Backs&lt;br&gt;RB - Right Backs&lt;br&gt;CB - Center Backs&lt;br&gt;DM - Defensive Midfielders&lt;br&gt;CM - Central Midfielders&lt;br&gt;LM - Left Midfielders&lt;br&gt;RM - Right Midfielders&lt;br&gt;WM - Wide Midfielders&lt;br&gt;LW - Left Wingers&lt;br&gt;RW - Right Wingers&lt;br&gt;AM - Attacking Midfielders&lt;br&gt;" scope="col">Pos</th> <th aria-label="Age" class="poptip sort_default_asc center" data-stat="age" data-tip="Age at season start&lt;br&gt;Given on August 1 for winter leagues&lt;br&gt;and February 1 for summer leagues." scope="col">Age</th> <th aria-label="Matches Played" class="poptip center group_start" data-stat="games" data-tip="&lt;strong&gt;Matches Played&lt;/strong&gt;&lt;br&gt;Matches Played by the player or squad" scope="col">MP</th> <th aria-label="Starts" class="poptip center" data-over-header="Playing Time" data-stat="games_starts" data-tip="Game or games started by player" scope="col">Starts</th> <th aria-label="Minutes" class="poptip center" data-over-header="Playing Time" data-stat="minutes" data-tip="&lt;strong&gt;Minutes&lt;/strong&gt;&lt;br&gt;" scope="col">Min</th> <th aria-label="90s Played" class="poptip center" data-over-header="Playing Time" data-stat="minutes_90s" data-tip="&lt;strong&gt;90s Played&lt;/strong&gt;&lt;br&gt;&lt;strong&gt;90s played&lt;/strong&gt;&lt;br&gt;Minutes played divided by 90" scope="col">90s</th> <th aria-label="Goals" class="poptip center group_start" data-over-header="Performance" data-stat="goals" data-tip="&lt;strong&gt;Goals&lt;/strong&gt;&lt;br&gt;Goals scored or allowed" scope="col">Gls</th> <th aria-label="Assists" class="poptip center" data-over-header="Performance" data-stat="assists" data-tip="&lt;strong&gt;Assists&lt;/strong&gt;&lt;br&gt;Assists" scope="col">Ast</th> <th aria-label="Goals + Assists" class="poptip center" data-over-header="Performance" data-stat="goals_assists" data-tip="&lt;strong&gt;Goals + Assists&lt;/strong&gt;&lt;br&gt;Goals and Assists" scope="col">G+A</th> <th aria-label="Non-Penalty Goals" class="poptip center" data-over-head ...
#  <table class="stats_table sortable min_width" data-cols-to-freeze=",1" id="matchlogs_for"> <caption>Scores &amp; Fixtures <span style="color: #666; font-size:smaller">2021-2022 Norwich City: All Competitions</span> Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr> <th aria-label="Date" class="poptip sort_default_asc center" data-stat="date" data-tip="Date listed is local to the match" scope="col">Date</th> <th aria-label="Time" class="poptip sort_default_asc center" data-stat="start_time" data-tip="Time listed is local to the match venue&lt;br&gt;Time is written in the 24-hour notation&lt;br&gt;Your local time is in (·) " scope="col">Time</th> <th aria-label="Competition" class="poptip sort_default_asc center" data-stat="comp" data-tip="&lt;strong&gt;Competition&lt;/strong&gt;&lt;br&gt;Competition&lt;br&gt;Number next to competition states which level in the country's league pyramid this league occupies." scope="col">Comp</th> <th aria-label="Round" class="poptip center" data-stat="round" data-tip="Round or Phase of Competition" scope="col">Round</th> <th aria-label="Day" class="poptip sort_default_asc center" data-stat="dayofweek" data-tip="Day of week" scope="col">Day</th> <th aria-label="Venue" class="poptip sort_default_asc center" data-stat="venue" scope="col">Venue</th> <th aria-label="Result" class="poptip center" data-stat="result" scope="col">Result</th> <th aria-label="Goals For" class="poptip center" data-stat="goals_for" data-tip="&lt;strong&gt;Goals For&lt;/strong&gt;&lt;br&gt;Goals For" scope="col">GF</th> <th aria-label="Goals Against" class="poptip center" data-stat="goals_against" data-tip="&lt;strong&gt;Goals Against&lt;/strong&gt;&lt;br&gt;Goals Against" scope="col">GA</th> <th aria-label="Opponent" class="poptip sort_default_asc center" data-stat="opponent" scope="col">Opponent</th> <th aria-label="xG" class="poptip center" data-filter="1" data-name="xG" data-stat="xg_for" data-tip="&lt;strong&gt;Expected Goals&lt;/strong&gt;&lt;br&gt;xG totals include penalty kicks, but do not include penalty shootouts (unless otherwise noted).&lt;br&gt;Provided by Opta.&lt;br&gt;An underline indicates there is a match that is missing data, but will be updated when available." scope="col">xG</th> <th aria-label="xG Allowed" class="poptip sort_default_asc center" data-stat="xg_against" data-tip="&lt;strong&gt;xG Allowed&lt;/strong&gt;&lt;br&gt;&lt;strong&gt;Expected Goals Allowed&lt;/strong&gt;&lt;br&gt;xG totals include penalty kicks, but do not include penalty shootouts (unless otherwise noted).&lt;br&gt;Provided by Opta.&lt;br&gt;An underline indicates there is a match that is missing data, but will be updated when available." scope="col">xGA</th> <th aria-label="Possession" class="poptip center" data-stat="possession" data-tip="&lt;strong&gt;Possession&lt;/strong&gt;&lt;br&gt;&lt;strong&gt;Possession&lt;/strong&gt;&lt;br&gt;Calculated as the percentage of passes attempted" scope="col">Poss</th> <th aria-label="Attendance" class="poptip center" data-stat="attendance" scope="col">Attendance</th> <th aria-label="Captain" class="poptip sort_default_asc center" data-stat="captain" scope="col">Captain</th> <th aria-label="Formation" class="poptip sort_default_asc center" data-stat="formation" data-tip="Number of players in each row from defenders to forwards, not including the goalkeeper.&lt;br&gt;Formations provided by Data Sports Group and Opta." scope="col">Formation</th> <th aria-label="Referee" class="poptip sort_default_asc center" data-stat="referee" scope="col">Referee</th> <th aria-label="Match Report" class="poptip center group_start" data-stat="match_report" scope="col">Match Report</th> <th aria-label="Notes" class="poptip center" data-stat="notes" scope="col">Notes</th> </tr> </thead> <tbody> <tr><th class="left" csk="20210814" data-stat="date" scope="row"><a href="/en/matches/c52500ad/Norwich-City- ...
#  <table class="stats_table sortable min_width" data-cols-to-freeze=",1" id="stats_keeper_9"> <caption>Goalkeeping <span style="color: #666; font-size:smaller">2021-2022 Norwich City: Premier League</span> Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr class="over_header"> <th aria-label="" class="over_header center" colspan="4" data-stat=""></th> <th aria-label="" class="over_header center group_start" colspan="4" data-stat="header_playing">Playing Time</th> <th aria-label="" class="over_header center group_start" colspan="10" data-stat="header_performance">Performance</th> <th aria-label="" class="over_header center group_start" colspan="5" data-stat="header_pk">Penalty Kicks</th><th></th> </tr> <tr> <th aria-label="Player" class="poptip sort_default_asc left" data-stat="player" scope="col">Player</th> <th aria-label="Nation" class="poptip sort_default_asc center" data-stat="nationality" data-tip="Nationality of the player.&lt;br&gt;First, we check our records in international play at senior level.&lt;br&gt;Then youth level.&lt;br&gt;Then citizenship presented on wikipedia.&lt;br&gt;Finally, we use their birthplace when available." scope="col">Nation</th> <th aria-label="Position" class="poptip center" data-stat="position" data-tip="&lt;strong&gt;Position&lt;/strong&gt;&lt;br&gt;Position most commonly played by the player&lt;br&gt;GK - Goalkeepers&lt;br&gt;DF - Defenders&lt;br&gt;MF - Midfielders&lt;br&gt;FW - Forwards&lt;br&gt;FB - Fullbacks&lt;br&gt;LB - Left Backs&lt;br&gt;RB - Right Backs&lt;br&gt;CB - Center Backs&lt;br&gt;DM - Defensive Midfielders&lt;br&gt;CM - Central Midfielders&lt;br&gt;LM - Left Midfielders&lt;br&gt;RM - Right Midfielders&lt;br&gt;WM - Wide Midfielders&lt;br&gt;LW - Left Wingers&lt;br&gt;RW - Right Wingers&lt;br&gt;AM - Attacking Midfielders&lt;br&gt;" scope="col">Pos</th> <th aria-label="Age" class="poptip sort_default_asc center" data-stat="age" data-tip="Age at season start&lt;br&gt;Given on August 1 for winter leagues&lt;br&gt;and February 1 for summer leagues." scope="col">Age</th> <th aria-label="Matches Played" class="poptip center group_start" data-over-header="Playing Time" data-stat="gk_games" data-tip="&lt;strong&gt;Matches Played&lt;/strong&gt;&lt;br&gt;Matches Played by the player or squad" scope="col">MP</th> <th aria-label="Starts" class="poptip center" data-over-header="Playing Time" data-stat="gk_games_starts" data-tip="Game or games started by player" scope="col">Starts</th> <th aria-label="Minutes" class="poptip center" data-over-header="Playing Time" data-stat="gk_minutes" data-tip="&lt;strong&gt;Minutes&lt;/strong&gt;&lt;br&gt;" scope="col">Min</th> <th aria-label="90s Played" class="poptip center" data-over-header="Playing Time" data-stat="minutes_90s" data-tip="&lt;strong&gt;90s Played&lt;/strong&gt;&lt;br&gt;&lt;strong&gt;90s played&lt;/strong&gt;&lt;br&gt;Minutes played divided by 90" scope="col">90s</th> <th aria-label="Goals Against" class="poptip center group_start" data-over-header="Performance" data-stat="gk_goals_against" data-tip="&lt;strong&gt;Goals Against&lt;/strong&gt;&lt;br&gt;Goals Against" scope="col">GA</th> <th aria-label="Goals Against/90" class="poptip sort_default_asc hide_non_quals center" data-filter="1" data-name="Goals Against/90" data-over-header="Performance" data-stat="gk_goals_against_per90" data-tip="&lt;strong&gt;Goals Against/90&lt;/strong&gt;&lt;br&gt;Goals Against per 90 minutes" scope="col">GA90</th> <th aria-label="Shots on Target Against" class="poptip center" data-over-header="Performance" data-stat="gk_shots_on_target_against" data-tip="&lt;strong&gt;Shots on Target Against&lt;/strong&gt;&lt;br&gt;Shots on Target Against" scope="col">SoTA</th> <th aria-label="Saves" class="poptip center" data-over-header="Performance" data-stat="gk_saves" scope="col">Saves</th> <th aria-label="Save Percentage" ...
#  <table class="stats_table sortable min_width" data-cols-to-freeze=",1" id="stats_keeper_adv_9"> <caption>Advanced Goalkeeping <span style="color: #666; font-size:smaller">2021-2022 Norwich City: Premier League</span> Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr class="over_header"> <th aria-label="" class="over_header center" colspan="5" data-stat=""></th> <th aria-label="" class="over_header center group_start" colspan="5" data-stat="header_goals">Goals</th> <th aria-label="" class="over_header center group_start" colspan="4" data-stat="header_expected">Expected</th> <th aria-label="" class="over_header center group_start" colspan="3" data-stat="header_passes_launched">Launched</th> <th aria-label="" class="over_header center group_start" colspan="4" data-stat="header_passes">Passes</th> <th aria-label="" class="over_header center group_start" colspan="3" data-stat="header_goal_kicks">Goal Kicks</th> <th aria-label="" class="over_header center group_start" colspan="3" data-stat="header_crosses_gk">Crosses</th> <th aria-label="" class="over_header center group_start" colspan="3" data-stat="header_sweeper">Sweeper</th><th></th> </tr> <tr> <th aria-label="Player" class="poptip sort_default_asc left" data-stat="player" scope="col">Player</th> <th aria-label="Nation" class="poptip sort_default_asc center" data-stat="nationality" data-tip="Nationality of the player.&lt;br&gt;First, we check our records in international play at senior level.&lt;br&gt;Then youth level.&lt;br&gt;Then citizenship presented on wikipedia.&lt;br&gt;Finally, we use their birthplace when available." scope="col">Nation</th> <th aria-label="Position" class="poptip center" data-stat="position" data-tip="&lt;strong&gt;Position&lt;/strong&gt;&lt;br&gt;Position most commonly played by the player&lt;br&gt;GK - Goalkeepers&lt;br&gt;DF - Defenders&lt;br&gt;MF - Midfielders&lt;br&gt;FW - Forwards&lt;br&gt;FB - Fullbacks&lt;br&gt;LB - Left Backs&lt;br&gt;RB - Right Backs&lt;br&gt;CB - Center Backs&lt;br&gt;DM - Defensive Midfielders&lt;br&gt;CM - Central Midfielders&lt;br&gt;LM - Left Midfielders&lt;br&gt;RM - Right Midfielders&lt;br&gt;WM - Wide Midfielders&lt;br&gt;LW - Left Wingers&lt;br&gt;RW - Right Wingers&lt;br&gt;AM - Attacking Midfielders&lt;br&gt;" scope="col">Pos</th> <th aria-label="Age" class="poptip sort_default_asc center" data-stat="age" data-tip="Age at season start&lt;br&gt;Given on August 1 for winter leagues&lt;br&gt;and February 1 for summer leagues." scope="col">Age</th> <th aria-label="90s Played" class="poptip center" data-stat="minutes_90s" data-tip="&lt;strong&gt;90s Played&lt;/strong&gt;&lt;br&gt;&lt;strong&gt;90s played&lt;/strong&gt;&lt;br&gt;Minutes played divided by 90" scope="col">90s</th> <th aria-label="Goals Against" class="poptip center group_start" data-over-header="Goals" data-stat="gk_goals_against" data-tip="&lt;strong&gt;Goals Against&lt;/strong&gt;&lt;br&gt;Goals Against" scope="col">GA</th> <th aria-label="Penalty Kicks Allowed" class="poptip center" data-over-header="Goals" data-stat="gk_pens_allowed" data-tip="&lt;strong&gt;Penalty Kicks Allowed&lt;/strong&gt;&lt;br&gt;Penalty Kicks Allowed" scope="col">PKA</th> <th aria-label="Free Kick Goals Against" class="poptip center" data-over-header="Goals" data-stat="gk_free_kick_goals_against" data-tip="&lt;strong&gt;Free Kick Goals Against&lt;/strong&gt;&lt;br&gt;Free Kick Goals Against" scope="col">FK</th> <th aria-label="Corner Kick Goals Against" class="poptip center" data-over-header="Goals" data-stat="gk_corner_kick_goals_against" data-tip="&lt;strong&gt;Corner Kick Goals Against&lt;/strong&gt;&lt;br&gt;Corner Kick Goals Against" scope="col">CK</th> <th aria-label="Own Goals Scored Against Goalkeeper" class="poptip center" data-over-header="Goals" data-stat="gk_own_goals_against" data-t ...
#  <table class="stats_table sortable min_width" data-cols-to-freeze=",1" id="stats_shooting_9"> <caption>Shooting <span style="color: #666; font-size:smaller">2021-2022 Norwich City: Premier League</span> Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr class="over_header"> <th aria-label="" class="over_header center" colspan="5" data-stat=""></th> <th aria-label="" class="over_header center group_start" colspan="12" data-stat="header_standard">Standard</th> <th aria-label="" class="over_header center group_start" colspan="5" data-stat="header_expected">Expected</th><th></th> </tr> <tr> <th aria-label="Player" class="poptip sort_default_asc left" data-stat="player" scope="col">Player</th> <th aria-label="Nation" class="poptip sort_default_asc center" data-stat="nationality" data-tip="Nationality of the player.&lt;br&gt;First, we check our records in international play at senior level.&lt;br&gt;Then youth level.&lt;br&gt;Then citizenship presented on wikipedia.&lt;br&gt;Finally, we use their birthplace when available." scope="col">Nation</th> <th aria-label="Position" class="poptip center" data-stat="position" data-tip="&lt;strong&gt;Position&lt;/strong&gt;&lt;br&gt;Position most commonly played by the player&lt;br&gt;GK - Goalkeepers&lt;br&gt;DF - Defenders&lt;br&gt;MF - Midfielders&lt;br&gt;FW - Forwards&lt;br&gt;FB - Fullbacks&lt;br&gt;LB - Left Backs&lt;br&gt;RB - Right Backs&lt;br&gt;CB - Center Backs&lt;br&gt;DM - Defensive Midfielders&lt;br&gt;CM - Central Midfielders&lt;br&gt;LM - Left Midfielders&lt;br&gt;RM - Right Midfielders&lt;br&gt;WM - Wide Midfielders&lt;br&gt;LW - Left Wingers&lt;br&gt;RW - Right Wingers&lt;br&gt;AM - Attacking Midfielders&lt;br&gt;" scope="col">Pos</th> <th aria-label="Age" class="poptip sort_default_asc center" data-stat="age" data-tip="Age at season start&lt;br&gt;Given on August 1 for winter leagues&lt;br&gt;and February 1 for summer leagues." scope="col">Age</th> <th aria-label="90s Played" class="poptip center" data-stat="minutes_90s" data-tip="&lt;strong&gt;90s Played&lt;/strong&gt;&lt;br&gt;&lt;strong&gt;90s played&lt;/strong&gt;&lt;br&gt;Minutes played divided by 90" scope="col">90s</th> <th aria-label="Goals" class="poptip center group_start" data-over-header="Standard" data-stat="goals" data-tip="&lt;strong&gt;Goals&lt;/strong&gt;&lt;br&gt;Goals scored or allowed" scope="col">Gls</th> <th aria-label="Shots Total" class="poptip center" data-over-header="Standard" data-stat="shots" data-tip="&lt;strong&gt;Shots Total&lt;/strong&gt;&lt;br&gt;Shots Total&lt;br&gt;Does not include penalty kicks" scope="col">Sh</th> <th aria-label="Shots on Target" class="poptip center" data-over-header="Standard" data-stat="shots_on_target" data-tip="&lt;strong&gt;Shots on Target&lt;/strong&gt;&lt;br&gt;Shots on Target&lt;br&gt;Note: Shots on target do not include penalty kicks" scope="col">SoT</th> <th aria-label="Shots on Target %" class="poptip hide_non_quals center" data-filter="1" data-name="Shots on Target %" data-over-header="Standard" data-stat="shots_on_target_pct" data-tip="&lt;strong&gt;Shots on Target %&lt;/strong&gt;&lt;br&gt;Percentage of shots that are on target&lt;br&gt;Minimum .395 shots per squad game to qualify as a leader&lt;br&gt;Note: Shots on target do not include penalty kicks" scope="col">SoT%</th> <th aria-label="Shots Total/90" class="poptip hide_non_quals center" data-filter="1" data-name="Shots Total/90" data-over-header="Standard" data-stat="shots_per90" data-tip="&lt;strong&gt;Shots Total/90&lt;/strong&gt;&lt;br&gt;Shots total per 90 minutes&lt;br&gt;Minimum 30 minutes played per squad game to qualify as a leader" scope="col">Sh/90</th> <th aria-label="Shots on target/90" class="poptip hide_non_quals center" data-filter="1" data-name="Shots on target/90" data-over-header="Standard" data-stat="shots_on_target_per90" data-tip="&lt;strong&gt; ...
#  <table class="stats_table sortable min_width" data-cols-to-freeze=",1" id="stats_passing_9"> <caption>Passing <span style="color: #666; font-size:smaller">2021-2022 Norwich City: Premier League</span> Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr class="over_header"> <th aria-label="" class="over_header center" colspan="5" data-stat=""></th> <th aria-label="" class="over_header center group_start" colspan="5" data-stat="header_passes_total">Total</th> <th aria-label="" class="over_header center group_start" colspan="3" data-stat="header_passes_short">Short</th> <th aria-label="" class="over_header center group_start" colspan="3" data-stat="header_passes_medium">Medium</th> <th aria-label="" class="over_header center group_start" colspan="3" data-stat="header_passes_long">Long</th> <th aria-label="" class="over_header center" colspan="2" data-stat=""></th> <th aria-label="" class="over_header center group_start" colspan="2" data-stat="header_expected">Expected</th> <th aria-label="" class="over_header center" colspan="5" data-stat=""></th><th></th> </tr> <tr> <th aria-label="Player" class="poptip sort_default_asc left" data-stat="player" scope="col">Player</th> <th aria-label="Nation" class="poptip sort_default_asc center" data-stat="nationality" data-tip="Nationality of the player.&lt;br&gt;First, we check our records in international play at senior level.&lt;br&gt;Then youth level.&lt;br&gt;Then citizenship presented on wikipedia.&lt;br&gt;Finally, we use their birthplace when available." scope="col">Nation</th> <th aria-label="Position" class="poptip center" data-stat="position" data-tip="&lt;strong&gt;Position&lt;/strong&gt;&lt;br&gt;Position most commonly played by the player&lt;br&gt;GK - Goalkeepers&lt;br&gt;DF - Defenders&lt;br&gt;MF - Midfielders&lt;br&gt;FW - Forwards&lt;br&gt;FB - Fullbacks&lt;br&gt;LB - Left Backs&lt;br&gt;RB - Right Backs&lt;br&gt;CB - Center Backs&lt;br&gt;DM - Defensive Midfielders&lt;br&gt;CM - Central Midfielders&lt;br&gt;LM - Left Midfielders&lt;br&gt;RM - Right Midfielders&lt;br&gt;WM - Wide Midfielders&lt;br&gt;LW - Left Wingers&lt;br&gt;RW - Right Wingers&lt;br&gt;AM - Attacking Midfielders&lt;br&gt;" scope="col">Pos</th> <th aria-label="Age" class="poptip sort_default_asc center" data-stat="age" data-tip="Age at season start&lt;br&gt;Given on August 1 for winter leagues&lt;br&gt;and February 1 for summer leagues." scope="col">Age</th> <th aria-label="90s Played" class="poptip center" data-stat="minutes_90s" data-tip="&lt;strong&gt;90s Played&lt;/strong&gt;&lt;br&gt;&lt;strong&gt;90s played&lt;/strong&gt;&lt;br&gt;Minutes played divided by 90" scope="col">90s</th> <th aria-label="Passes Completed" class="poptip center group_start" data-over-header="Total" data-stat="passes_completed" data-tip="&lt;strong&gt;Passes Completed&lt;/strong&gt;&lt;br&gt;Passes Completed" scope="col">Cmp</th> <th aria-label="Passes Attempted" class="poptip center" data-over-header="Total" data-stat="passes" data-tip="&lt;strong&gt;Passes Attempted&lt;/strong&gt;&lt;br&gt;Passes Attempted" scope="col">Att</th> <th aria-label="Pass Completion %" class="poptip hide_non_quals center" data-filter="1" data-name="Pass Completion %" data-over-header="Total" data-stat="passes_pct" data-tip="&lt;strong&gt;Pass Completion %&lt;/strong&gt;&lt;br&gt;Pass Completion Percentage&lt;br&gt;Minimum 30 minutes played per squad game to qualify as a leader" scope="col">Cmp%</th> <th aria-label="Total Passing Distance" class="poptip center" data-over-header="Total" data-stat="passes_total_distance" data-tip="&lt;strong&gt;Total Passing Distance&lt;/strong&gt;&lt;br&gt;Total distance, in yards, that completed passes have traveled in any direction" scope="col">TotDist</th> <th aria-label="Progressive Passing Distance" class="poptip center" data-over-header="Total ...
#  <table class="stats_table sortable min_width" data-cols-to-freeze=",1" id="stats_passing_types_9"> <caption>Pass Types <span style="color: #666; font-size:smaller">2021-2022 Norwich City: Premier League</span> Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr class="over_header"> <th aria-label="" class="over_header center" colspan="6" data-stat=""></th> <th aria-label="" class="over_header center group_start" colspan="8" data-stat="header_pass_types">Pass Types</th> <th aria-label="" class="over_header center group_start" colspan="3" data-stat="header_corner_kicks">Corner Kicks</th> <th aria-label="" class="over_header center group_start" colspan="3" data-stat="header_pass_outcomes">Outcomes</th><th></th> </tr> <tr> <th aria-label="Player" class="poptip sort_default_asc left" data-stat="player" scope="col">Player</th> <th aria-label="Nation" class="poptip sort_default_asc center" data-stat="nationality" data-tip="Nationality of the player.&lt;br&gt;First, we check our records in international play at senior level.&lt;br&gt;Then youth level.&lt;br&gt;Then citizenship presented on wikipedia.&lt;br&gt;Finally, we use their birthplace when available." scope="col">Nation</th> <th aria-label="Position" class="poptip center" data-stat="position" data-tip="&lt;strong&gt;Position&lt;/strong&gt;&lt;br&gt;Position most commonly played by the player&lt;br&gt;GK - Goalkeepers&lt;br&gt;DF - Defenders&lt;br&gt;MF - Midfielders&lt;br&gt;FW - Forwards&lt;br&gt;FB - Fullbacks&lt;br&gt;LB - Left Backs&lt;br&gt;RB - Right Backs&lt;br&gt;CB - Center Backs&lt;br&gt;DM - Defensive Midfielders&lt;br&gt;CM - Central Midfielders&lt;br&gt;LM - Left Midfielders&lt;br&gt;RM - Right Midfielders&lt;br&gt;WM - Wide Midfielders&lt;br&gt;LW - Left Wingers&lt;br&gt;RW - Right Wingers&lt;br&gt;AM - Attacking Midfielders&lt;br&gt;" scope="col">Pos</th> <th aria-label="Age" class="poptip sort_default_asc center" data-stat="age" data-tip="Age at season start&lt;br&gt;Given on August 1 for winter leagues&lt;br&gt;and February 1 for summer leagues." scope="col">Age</th> <th aria-label="90s Played" class="poptip center" data-stat="minutes_90s" data-tip="&lt;strong&gt;90s Played&lt;/strong&gt;&lt;br&gt;&lt;strong&gt;90s played&lt;/strong&gt;&lt;br&gt;Minutes played divided by 90" scope="col">90s</th> <th aria-label="Passes Attempted" class="poptip center" data-stat="passes" data-tip="&lt;strong&gt;Passes Attempted&lt;/strong&gt;&lt;br&gt;Passes Attempted" scope="col">Att</th> <th aria-label="Live-ball Passes" class="poptip center group_start" data-over-header="Pass Types" data-stat="passes_live" data-tip="&lt;strong&gt;Live-ball Passes&lt;/strong&gt;&lt;br&gt;Live-ball Passes" scope="col">Live</th> <th aria-label="Dead-ball Passes" class="poptip center" data-over-header="Pass Types" data-stat="passes_dead" data-tip="&lt;strong&gt;Dead-ball Passes&lt;/strong&gt;&lt;br&gt;Dead-ball Passes&lt;br&gt;Includes free kicks, corner kicks, kick offs, throw-ins and goal kicks" scope="col">Dead</th> <th aria-label="Passes from Free Kicks" class="poptip center" data-over-header="Pass Types" data-stat="passes_free_kicks" data-tip="&lt;strong&gt;Passes from Free Kicks&lt;/strong&gt;&lt;br&gt;Passes attempted from free kicks" scope="col">FK</th> <th aria-label="Through Balls" class="poptip center" data-over-header="Pass Types" data-stat="through_balls" data-tip="&lt;strong&gt;Through Balls&lt;/strong&gt;&lt;br&gt;Completed pass sent between back defenders into open space" scope="col">TB</th> <th aria-label="Switches" class="poptip center" data-over-header="Pass Types" data-stat="passes_switches" data-tip="&lt;strong&gt;Switches&lt;/strong&gt;&lt;br&gt;Passes that travel more than 40 yards of the width of the pitch" scope="col">Sw</th> <th aria-label="Crosses" class="poptip center" data-over-header="Pass Types" data-stat="crosses" data-tip="&lt;strong&gt;Cross ...
#  <table class="stats_table sortable min_width" data-cols-to-freeze=",1" id="stats_gca_9"> <caption>Goal and Shot Creation <span style="color: #666; font-size:smaller">2021-2022 Norwich City: Premier League</span> Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr class="over_header"> <th aria-label="" class="over_header center" colspan="5" data-stat=""></th> <th aria-label="" class="over_header center group_start" colspan="2" data-stat="header_sca">SCA</th> <th aria-label="" class="over_header center group_start" colspan="6" data-stat="header_sca_types">SCA Types</th> <th aria-label="" class="over_header center group_start" colspan="2" data-stat="header_gca">GCA</th> <th aria-label="" class="over_header center group_start" colspan="6" data-stat="header_gca_types">GCA Types</th><th></th> </tr> <tr> <th aria-label="Player" class="poptip sort_default_asc left" data-stat="player" scope="col">Player</th> <th aria-label="Nation" class="poptip sort_default_asc center" data-stat="nationality" data-tip="Nationality of the player.&lt;br&gt;First, we check our records in international play at senior level.&lt;br&gt;Then youth level.&lt;br&gt;Then citizenship presented on wikipedia.&lt;br&gt;Finally, we use their birthplace when available." scope="col">Nation</th> <th aria-label="Position" class="poptip center" data-stat="position" data-tip="&lt;strong&gt;Position&lt;/strong&gt;&lt;br&gt;Position most commonly played by the player&lt;br&gt;GK - Goalkeepers&lt;br&gt;DF - Defenders&lt;br&gt;MF - Midfielders&lt;br&gt;FW - Forwards&lt;br&gt;FB - Fullbacks&lt;br&gt;LB - Left Backs&lt;br&gt;RB - Right Backs&lt;br&gt;CB - Center Backs&lt;br&gt;DM - Defensive Midfielders&lt;br&gt;CM - Central Midfielders&lt;br&gt;LM - Left Midfielders&lt;br&gt;RM - Right Midfielders&lt;br&gt;WM - Wide Midfielders&lt;br&gt;LW - Left Wingers&lt;br&gt;RW - Right Wingers&lt;br&gt;AM - Attacking Midfielders&lt;br&gt;" scope="col">Pos</th> <th aria-label="Age" class="poptip sort_default_asc center" data-stat="age" data-tip="Age at season start&lt;br&gt;Given on August 1 for winter leagues&lt;br&gt;and February 1 for summer leagues." scope="col">Age</th> <th aria-label="90s Played" class="poptip center" data-stat="minutes_90s" data-tip="&lt;strong&gt;90s Played&lt;/strong&gt;&lt;br&gt;&lt;strong&gt;90s played&lt;/strong&gt;&lt;br&gt;Minutes played divided by 90" scope="col">90s</th> <th aria-label="Shot-Creating Actions" class="poptip center group_start" data-over-header="SCA" data-stat="sca" data-tip="&lt;strong&gt;Shot-Creating Actions&lt;/strong&gt;&lt;br&gt;Shot-Creating Actions&lt;br&gt;The two offensive actions directly leading to a shot, such as passes, take-ons and drawing fouls. Note: A single player can receive credit for multiple actions and the shot-taker can also receive credit." scope="col">SCA</th> <th aria-label="Shot-Creating Actions/90" class="poptip hide_non_quals center" data-filter="1" data-name="Shot-Creating Actions/90" data-over-header="SCA" data-stat="sca_per90" data-tip="&lt;strong&gt;Shot-Creating Actions/90&lt;/strong&gt;&lt;br&gt;Shot-Creating Actions per 90 minutes&lt;br&gt;Minimum 30 minutes played per squad game to qualify as a leader" scope="col">SCA90</th> <th aria-label="SCA (Live-ball Pass)" class="poptip center group_start" data-over-header="SCA Types" data-stat="sca_passes_live" data-tip="&lt;strong&gt;SCA (Live-ball Pass)&lt;/strong&gt;&lt;br&gt;Completed live-ball passes that lead to a shot attempt" scope="col">PassLive</th> <th aria-label="SCA (Dead-ball Pass)" class="poptip center" data-over-header="SCA Types" data-stat="sca_passes_dead" data-tip="&lt;strong&gt;SCA (Dead-ball Pass)&lt;/strong&gt;&lt;br&gt;Completed dead-ball passes that lead to a shot attempt.&lt;br&gt;Includes free kicks, corner kicks, kick offs, throw-ins and goal kicks" scope="col">PassDead</th> <th aria-label="SCA (Take-On)" clas ...
#  <table class="stats_table sortable min_width" data-cols-to-freeze=",1" id="stats_defense_9"> <caption>Defensive Actions <span style="color: #666; font-size:smaller">2021-2022 Norwich City: Premier League</span> Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr class="over_header"> <th aria-label="" class="over_header center" colspan="5" data-stat=""></th> <th aria-label="" class="over_header center group_start" colspan="5" data-stat="header_tackles">Tackles</th> <th aria-label="" class="over_header center group_start" colspan="4" data-stat="header_challenges">Challenges</th> <th aria-label="" class="over_header center group_start" colspan="3" data-stat="header_blocks">Blocks</th> <th aria-label="" class="over_header center" colspan="4" data-stat=""></th><th></th> </tr> <tr> <th aria-label="Player" class="poptip sort_default_asc left" data-stat="player" scope="col">Player</th> <th aria-label="Nation" class="poptip sort_default_asc center" data-stat="nationality" data-tip="Nationality of the player.&lt;br&gt;First, we check our records in international play at senior level.&lt;br&gt;Then youth level.&lt;br&gt;Then citizenship presented on wikipedia.&lt;br&gt;Finally, we use their birthplace when available." scope="col">Nation</th> <th aria-label="Position" class="poptip center" data-stat="position" data-tip="&lt;strong&gt;Position&lt;/strong&gt;&lt;br&gt;Position most commonly played by the player&lt;br&gt;GK - Goalkeepers&lt;br&gt;DF - Defenders&lt;br&gt;MF - Midfielders&lt;br&gt;FW - Forwards&lt;br&gt;FB - Fullbacks&lt;br&gt;LB - Left Backs&lt;br&gt;RB - Right Backs&lt;br&gt;CB - Center Backs&lt;br&gt;DM - Defensive Midfielders&lt;br&gt;CM - Central Midfielders&lt;br&gt;LM - Left Midfielders&lt;br&gt;RM - Right Midfielders&lt;br&gt;WM - Wide Midfielders&lt;br&gt;LW - Left Wingers&lt;br&gt;RW - Right Wingers&lt;br&gt;AM - Attacking Midfielders&lt;br&gt;" scope="col">Pos</th> <th aria-label="Age" class="poptip sort_default_asc center" data-stat="age" data-tip="Age at season start&lt;br&gt;Given on August 1 for winter leagues&lt;br&gt;and February 1 for summer leagues." scope="col">Age</th> <th aria-label="90s Played" class="poptip center" data-stat="minutes_90s" data-tip="&lt;strong&gt;90s Played&lt;/strong&gt;&lt;br&gt;&lt;strong&gt;90s played&lt;/strong&gt;&lt;br&gt;Minutes played divided by 90" scope="col">90s</th> <th aria-label="Tackles" class="poptip center group_start" data-over-header="Tackles" data-stat="tackles" data-tip="&lt;strong&gt;Tackles&lt;/strong&gt;&lt;br&gt;Number of players tackled" scope="col">Tkl</th> <th aria-label="Tackles Won" class="poptip center" data-over-header="Tackles" data-stat="tackles_won" data-tip="&lt;strong&gt;Tackles Won&lt;/strong&gt;&lt;br&gt;Tackles in which the tackler's team won possession of the ball" scope="col">TklW</th> <th aria-label="Tackles (Def 3rd)" class="poptip center" data-over-header="Tackles" data-stat="tackles_def_3rd" data-tip="&lt;strong&gt;Tackles (Def 3rd)&lt;/strong&gt;&lt;br&gt;Tackles in defensive 1/3" scope="col">Def 3rd</th> <th aria-label="Tackles (Mid 3rd)" class="poptip center" data-over-header="Tackles" data-stat="tackles_mid_3rd" data-tip="&lt;strong&gt;Tackles (Mid 3rd)&lt;/strong&gt;&lt;br&gt;Tackles in middle 1/3" scope="col">Mid 3rd</th> <th aria-label="Tackles (Att 3rd)" class="poptip center" data-over-header="Tackles" data-stat="tackles_att_3rd" data-tip="&lt;strong&gt;Tackles (Att 3rd)&lt;/strong&gt;&lt;br&gt;Tackles in attacking 1/3" scope="col">Att 3rd</th> <th aria-label="Dribblers Tackled" class="poptip center group_start" data-over-header="Challenges" data-stat="challenge_tackles" data-tip="&lt;strong&gt;Dribblers Tackled&lt;/strong&gt;&lt;br&gt;Number of dribblers tackled" scope="col">Tkl</th> <th aria-label="Dribbles Challenged" class="poptip center" data-over-header="Challenges" data-stat="challenges" data-tip=" ...
#  <table class="stats_table sortable min_width" data-cols-to-freeze=",1" id="stats_possession_9"> <caption>Possession <span style="color: #666; font-size:smaller">2021-2022 Norwich City: Premier League</span> Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr class="over_header"> <th aria-label="" class="over_header center" colspan="5" data-stat=""></th> <th aria-label="" class="over_header center group_start" colspan="7" data-stat="header_touches">Touches</th> <th aria-label="" class="over_header center group_start" colspan="5" data-stat="header_take_ons">Take-Ons</th> <th aria-label="" class="over_header center group_start" colspan="8" data-stat="header_carries">Carries</th> <th aria-label="" class="over_header center group_start" colspan="2" data-stat="header_receiving">Receiving</th><th></th> </tr> <tr> <th aria-label="Player" class="poptip sort_default_asc left" data-stat="player" scope="col">Player</th> <th aria-label="Nation" class="poptip sort_default_asc center" data-stat="nationality" data-tip="Nationality of the player.&lt;br&gt;First, we check our records in international play at senior level.&lt;br&gt;Then youth level.&lt;br&gt;Then citizenship presented on wikipedia.&lt;br&gt;Finally, we use their birthplace when available." scope="col">Nation</th> <th aria-label="Position" class="poptip center" data-stat="position" data-tip="&lt;strong&gt;Position&lt;/strong&gt;&lt;br&gt;Position most commonly played by the player&lt;br&gt;GK - Goalkeepers&lt;br&gt;DF - Defenders&lt;br&gt;MF - Midfielders&lt;br&gt;FW - Forwards&lt;br&gt;FB - Fullbacks&lt;br&gt;LB - Left Backs&lt;br&gt;RB - Right Backs&lt;br&gt;CB - Center Backs&lt;br&gt;DM - Defensive Midfielders&lt;br&gt;CM - Central Midfielders&lt;br&gt;LM - Left Midfielders&lt;br&gt;RM - Right Midfielders&lt;br&gt;WM - Wide Midfielders&lt;br&gt;LW - Left Wingers&lt;br&gt;RW - Right Wingers&lt;br&gt;AM - Attacking Midfielders&lt;br&gt;" scope="col">Pos</th> <th aria-label="Age" class="poptip sort_default_asc center" data-stat="age" data-tip="Age at season start&lt;br&gt;Given on August 1 for winter leagues&lt;br&gt;and February 1 for summer leagues." scope="col">Age</th> <th aria-label="90s Played" class="poptip center" data-stat="minutes_90s" data-tip="&lt;strong&gt;90s Played&lt;/strong&gt;&lt;br&gt;&lt;strong&gt;90s played&lt;/strong&gt;&lt;br&gt;Minutes played divided by 90" scope="col">90s</th> <th aria-label="Touches" class="poptip center group_start" data-over-header="Touches" data-stat="touches" data-tip="Number of times a player touched the ball. Note: Receiving a pass, then dribbling, then sending a pass counts as one touch" scope="col">Touches</th> <th aria-label="Touches (Def Pen)" class="poptip center" data-over-header="Touches" data-stat="touches_def_pen_area" data-tip="&lt;strong&gt;Touches (Def Pen)&lt;/strong&gt;&lt;br&gt;Touches in defensive penalty area" scope="col">Def Pen</th> <th aria-label="Touches (Def 3rd)" class="poptip center" data-over-header="Touches" data-stat="touches_def_3rd" data-tip="&lt;strong&gt;Touches (Def 3rd)&lt;/strong&gt;&lt;br&gt;Touches in defensive 1/3" scope="col">Def 3rd</th> <th aria-label="Touches (Mid 3rd)" class="poptip center" data-over-header="Touches" data-stat="touches_mid_3rd" data-tip="&lt;strong&gt;Touches (Mid 3rd)&lt;/strong&gt;&lt;br&gt;Touches in middle 1/3" scope="col">Mid 3rd</th> <th aria-label="Touches (Att 3rd)" class="poptip center" data-over-header="Touches" data-stat="touches_att_3rd" data-tip="&lt;strong&gt;Touches (Att 3rd)&lt;/strong&gt;&lt;br&gt;Touches in attacking 1/3" scope="col">Att 3rd</th> <th aria-label="Touches (Att Pen)" class="poptip center" data-over-header="Touches" data-stat="touches_att_pen_area" data-tip="&lt;strong&gt;Touches (Att Pen)&lt;/strong&gt;&lt;br&gt;Touches in attacking penalty area" scope="col">Att Pen</th> <th ari ...
#  <table class="stats_table sortable min_width" data-cols-to-freeze=",1" id="stats_playing_time_9"> <caption>Playing Time <span style="color: #666; font-size:smaller">2021-2022 Norwich City: Premier League</span> Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr class="over_header"> <th aria-label="" class="over_header center" colspan="4" data-stat=""></th><th></th> <th aria-label="" class="over_header center group_start" colspan="4" data-stat="header_playing">Playing Time</th> <th aria-label="" class="over_header center group_start" colspan="3" data-stat="header_starts">Starts</th> <th aria-label="" class="over_header center group_start" colspan="3" data-stat="header_subs">Subs</th> <th aria-label="" class="over_header center group_start" colspan="6" data-stat="header_team_success">Team Success</th> <th aria-label="" class="over_header center group_start" colspan="5" data-stat="header_xg_team_success">Team Success (xG)</th><th></th> </tr> <tr> <th aria-label="Player" class="poptip sort_default_asc left" data-stat="player" scope="col">Player</th> <th aria-label="Nation" class="poptip sort_default_asc center" data-stat="nationality" data-tip="Nationality of the player.&lt;br&gt;First, we check our records in international play at senior level.&lt;br&gt;Then youth level.&lt;br&gt;Then citizenship presented on wikipedia.&lt;br&gt;Finally, we use their birthplace when available." scope="col">Nation</th> <th aria-label="Position" class="poptip center" data-stat="position" data-tip="&lt;strong&gt;Position&lt;/strong&gt;&lt;br&gt;Position most commonly played by the player&lt;br&gt;GK - Goalkeepers&lt;br&gt;DF - Defenders&lt;br&gt;MF - Midfielders&lt;br&gt;FW - Forwards&lt;br&gt;FB - Fullbacks&lt;br&gt;LB - Left Backs&lt;br&gt;RB - Right Backs&lt;br&gt;CB - Center Backs&lt;br&gt;DM - Defensive Midfielders&lt;br&gt;CM - Central Midfielders&lt;br&gt;LM - Left Midfielders&lt;br&gt;RM - Right Midfielders&lt;br&gt;WM - Wide Midfielders&lt;br&gt;LW - Left Wingers&lt;br&gt;RW - Right Wingers&lt;br&gt;AM - Attacking Midfielders&lt;br&gt;" scope="col">Pos</th> <th aria-label="Age" class="poptip sort_default_asc center" data-stat="age" data-tip="Age at season start&lt;br&gt;Given on August 1 for winter leagues&lt;br&gt;and February 1 for summer leagues." scope="col">Age</th> <th aria-label="Matches Played" class="poptip center group_start" data-stat="games" data-tip="&lt;strong&gt;Matches Played&lt;/strong&gt;&lt;br&gt;Matches Played by the player or squad" scope="col">MP</th> <th aria-label="Minutes" class="poptip center" data-over-header="Playing Time" data-stat="minutes" data-tip="&lt;strong&gt;Minutes&lt;/strong&gt;&lt;br&gt;" scope="col">Min</th> <th aria-label="Minutes Per Match Played" class="poptip hide_non_quals center" data-over-header="Playing Time" data-stat="minutes_per_game" data-tip="&lt;strong&gt;Minutes Per Match Played&lt;/strong&gt;&lt;br&gt;Minutes Per Match Played" scope="col">Mn/MP</th> <th aria-label="Percentage of Squad Minutes Played" class="poptip hide_non_quals center" data-over-header="Playing Time" data-stat="minutes_pct" data-tip="&lt;strong&gt;Percentage of Squad Minutes Played&lt;/strong&gt;&lt;br&gt;&lt;strong&gt;Percentage of Minutes Played&lt;/strong&gt;&lt;br&gt;Percentage of team's total minutes in which player was on the pitch&lt;br&gt;Player minutes played divided by team total minutes played&lt;br&gt;Minimum 30 minutes played per squad game to qualify as a leader" scope="col">Min%</th> <th aria-label="90s Played" class="poptip center" data-over-header="Playing Time" data-stat="minutes_90s" data-tip="&lt;strong&gt;90s Played&lt;/strong&gt;&lt;br&gt;&lt;strong&gt;90s played&lt;/strong&gt;&lt;br&gt;Minutes played divided by 90" scope="col">90s</th> <th aria-label="Starts" class="poptip center group_start" data-over-header="Starts" data-stat="games_s ...
#  <table class="stats_table sortable min_width" data-cols-to-freeze=",1" id="stats_misc_9"> <caption>Miscellaneous Stats <span style="color: #666; font-size:smaller">2021-2022 Norwich City: Premier League</span> Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr class="over_header"> <th aria-label="" class="over_header center" colspan="5" data-stat=""></th> <th aria-label="" class="over_header center group_start" colspan="13" data-stat="header_performance">Performance</th> <th aria-label="" class="over_header center group_start" colspan="3" data-stat="header_aerials">Aerial Duels</th><th></th> </tr> <tr> <th aria-label="Player" class="poptip sort_default_asc left" data-stat="player" scope="col">Player</th> <th aria-label="Nation" class="poptip sort_default_asc center" data-stat="nationality" data-tip="Nationality of the player.&lt;br&gt;First, we check our records in international play at senior level.&lt;br&gt;Then youth level.&lt;br&gt;Then citizenship presented on wikipedia.&lt;br&gt;Finally, we use their birthplace when available." scope="col">Nation</th> <th aria-label="Position" class="poptip center" data-stat="position" data-tip="&lt;strong&gt;Position&lt;/strong&gt;&lt;br&gt;Position most commonly played by the player&lt;br&gt;GK - Goalkeepers&lt;br&gt;DF - Defenders&lt;br&gt;MF - Midfielders&lt;br&gt;FW - Forwards&lt;br&gt;FB - Fullbacks&lt;br&gt;LB - Left Backs&lt;br&gt;RB - Right Backs&lt;br&gt;CB - Center Backs&lt;br&gt;DM - Defensive Midfielders&lt;br&gt;CM - Central Midfielders&lt;br&gt;LM - Left Midfielders&lt;br&gt;RM - Right Midfielders&lt;br&gt;WM - Wide Midfielders&lt;br&gt;LW - Left Wingers&lt;br&gt;RW - Right Wingers&lt;br&gt;AM - Attacking Midfielders&lt;br&gt;" scope="col">Pos</th> <th aria-label="Age" class="poptip sort_default_asc center" data-stat="age" data-tip="Age at season start&lt;br&gt;Given on August 1 for winter leagues&lt;br&gt;and February 1 for summer leagues." scope="col">Age</th> <th aria-label="90s Played" class="poptip center" data-stat="minutes_90s" data-tip="&lt;strong&gt;90s Played&lt;/strong&gt;&lt;br&gt;&lt;strong&gt;90s played&lt;/strong&gt;&lt;br&gt;Minutes played divided by 90" scope="col">90s</th> <th aria-label="Yellow Cards" class="poptip center group_start" data-over-header="Performance" data-stat="cards_yellow" data-tip="&lt;strong&gt;Yellow Cards&lt;/strong&gt;&lt;br&gt;Yellow Cards" scope="col">CrdY</th> <th aria-label="Red Cards" class="poptip center" data-over-header="Performance" data-stat="cards_red" data-tip="&lt;strong&gt;Red Cards&lt;/strong&gt;&lt;br&gt;Red Cards" scope="col">CrdR</th> <th aria-label="Second Yellow Card" class="poptip center" data-over-header="Performance" data-stat="cards_yellow_red" data-tip="&lt;strong&gt;Second Yellow Card&lt;/strong&gt;&lt;br&gt;Second Yellow Card" scope="col">2CrdY</th> <th aria-label="Fouls Committed" class="poptip center" data-over-header="Performance" data-stat="fouls" data-tip="&lt;strong&gt;Fouls Committed&lt;/strong&gt;&lt;br&gt;Fouls Committed" scope="col">Fls</th> <th aria-label="Fouls Drawn" class="poptip center" data-over-header="Performance" data-stat="fouled" data-tip="&lt;strong&gt;Fouls Drawn&lt;/strong&gt;&lt;br&gt;Fouls Drawn" scope="col">Fld</th> <th aria-label="Offsides" class="poptip center" data-over-header="Performance" data-stat="offsides" data-tip="&lt;strong&gt;Offsides&lt;/strong&gt;&lt;br&gt;Offsides" scope="col">Off</th> <th aria-label="Crosses" class="poptip center" data-over-header="Performance" data-stat="crosses" data-tip="&lt;strong&gt;Crosses&lt;/strong&gt;&lt;br&gt;Crosses" scope="col">Crs</th> <th aria-label="Interceptions" class="poptip center" data-over-header="Performance" data-stat="interceptions" data-tip="&lt;strong&gt;Interceptions&lt;/strong&gt;&lt;br&gt;Interceptions" scope="col">Int</th> <th aria-label="Tackles Won" class="poptip center" data-over-heade ...
#  <table class="stats_table sortable min_width force_mobilize" data-cols-to-freeze=",2" id="results2021-202291_overall"> <caption>Regular season, Premier League Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr> <th aria-label="Rank" class="poptip sort_default_asc center" data-stat="rank" data-tip="&lt;strong&gt;Rank&lt;/strong&gt;&lt;br&gt;Squad finish in competition&lt;br&gt;Finish within the league or competition.&lt;br&gt;For knockout competitions may show final round reached.&lt;br&gt;Colors and arrows represent promotion/relegation or qualifiation for continental cups.&lt;br&gt;Trophy indicates team won league whether by playoffs or by leading the table.&lt;br&gt;Star indicates topped table in league USING another means of naming champion." scope="col">Rk</th> <th aria-label="Squad" class="poptip sort_default_asc center" data-stat="team" scope="col">Squad</th> <th aria-label="Matches Played" class="poptip center group_start" data-stat="games" data-tip="&lt;strong&gt;Matches Played&lt;/strong&gt;&lt;br&gt;Matches Played by the player or squad" scope="col">MP</th> <th aria-label="Wins" class="poptip center" data-stat="wins" data-tip="&lt;strong&gt;Wins&lt;/strong&gt;&lt;br&gt;Wins" scope="col">W</th> <th aria-label="Draws" class="poptip center" data-stat="ties" data-tip="&lt;strong&gt;Draws&lt;/strong&gt;&lt;br&gt;Draws" scope="col">D</th> <th aria-label="Losses" class="poptip center" data-stat="losses" data-tip="&lt;strong&gt;Losses&lt;/strong&gt;&lt;br&gt;Losses" scope="col">L</th> <th aria-label="Goals For" class="poptip center" data-stat="goals_for" data-tip="&lt;strong&gt;Goals For&lt;/strong&gt;&lt;br&gt;Goals For" scope="col">GF</th> <th aria-label="Goals Against" class="poptip center" data-stat="goals_against" data-tip="&lt;strong&gt;Goals Against&lt;/strong&gt;&lt;br&gt;Goals Against" scope="col">GA</th> <th aria-label="Goal Difference" class="poptip center" data-stat="goal_diff" data-tip="&lt;strong&gt;Goal Difference&lt;/strong&gt;&lt;br&gt;Goal Difference" scope="col">GD</th> <th aria-label="Points" class="poptip center" data-stat="points" data-tip="&lt;strong&gt;Points&lt;/strong&gt;&lt;br&gt;Most leagues are ordered by points.&lt;br&gt;Three for a win and one for a draw." scope="col">Pts</th> <th aria-label="Points/Match" class="poptip center" data-stat="points_avg" data-tip="&lt;strong&gt;Points/Match&lt;/strong&gt;&lt;br&gt;Points per Match Played" scope="col">Pts/MP</th> <th aria-label="xG" class="poptip center" data-filter="1" data-name="xG" data-stat="xg_for" data-tip="&lt;strong&gt;Expected Goals&lt;/strong&gt;&lt;br&gt;xG totals include penalty kicks, but do not include penalty shootouts (unless otherwise noted).&lt;br&gt;Provided by Opta.&lt;br&gt;An underline indicates there is a match that is missing data, but will be updated when available." scope="col">xG</th> <th aria-label="xG Allowed" class="poptip sort_default_asc center" data-stat="xg_against" data-tip="&lt;strong&gt;xG Allowed&lt;/strong&gt;&lt;br&gt;&lt;strong&gt;Expected Goals Allowed&lt;/strong&gt;&lt;br&gt;xG totals include penalty kicks, but do not include penalty shootouts (unless otherwise noted).&lt;br&gt;Provided by Opta.&lt;br&gt;An underline indicates there is a match that is missing data, but will be updated when available." scope="col">xGA</th> <th aria-label="xG Difference" class="poptip center" data-filter="1" data-name="xG Difference" data-stat="xg_diff" data-tip="&lt;strong&gt;xG Difference&lt;/strong&gt;&lt;br&gt;&lt;strong&gt;Expected Goals Difference&lt;/strong&gt;&lt;br&gt;xG totals include penalty kicks, but do not include penalty shootouts (unless otherwise noted).&lt;br&gt;Provided by Opta.&lt;br&gt;An underline indicates there is a match that is missing data, but will be updated when available." scope="col">xGD</th> <th aria-label="xG Difference/90" class="poptip hide_non_quals center" data-stat="xg_diff_p ...
#  <table class="stats_table sortable min_width force_mobilize" data-cols-to-freeze=",2" id="results2021-202291_home_away"> <caption>Regular season, Premier League Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr class="over_header"> <th aria-label="" class="over_header center" colspan="2" data-stat=""></th> <th aria-label="" class="over_header center group_start" colspan="13" data-stat="header_home">Home</th> <th aria-label="" class="over_header center group_start" colspan="13" data-stat="header_away">Away</th> </tr> <tr> <th aria-label="Rank" class="poptip sort_default_asc center" data-stat="rank" data-tip="&lt;strong&gt;Rank&lt;/strong&gt;&lt;br&gt;Squad finish in competition&lt;br&gt;Finish within the league or competition.&lt;br&gt;For knockout competitions may show final round reached.&lt;br&gt;Colors and arrows represent promotion/relegation or qualifiation for continental cups.&lt;br&gt;Trophy indicates team won league whether by playoffs or by leading the table.&lt;br&gt;Star indicates topped table in league USING another means of naming champion." scope="col">Rk</th> <th aria-label="Squad" class="poptip sort_default_asc center" data-stat="team" scope="col">Squad</th> <th aria-label="Matches Played" class="poptip center group_start" data-over-header="Home" data-stat="home_games" data-tip="&lt;strong&gt;Matches Played&lt;/strong&gt;&lt;br&gt;Matches Played by the player or squad" scope="col">MP</th> <th aria-label="Wins" class="poptip center" data-over-header="Home" data-stat="home_wins" data-tip="&lt;strong&gt;Wins&lt;/strong&gt;&lt;br&gt;Wins" scope="col">W</th> <th aria-label="Draws" class="poptip center" data-over-header="Home" data-stat="home_ties" data-tip="&lt;strong&gt;Draws&lt;/strong&gt;&lt;br&gt;Draws" scope="col">D</th> <th aria-label="Losses" class="poptip center" data-over-header="Home" data-stat="home_losses" data-tip="&lt;strong&gt;Losses&lt;/strong&gt;&lt;br&gt;Losses" scope="col">L</th> <th aria-label="Goals For" class="poptip center" data-over-header="Home" data-stat="home_goals_for" data-tip="&lt;strong&gt;Goals For&lt;/strong&gt;&lt;br&gt;Goals For" scope="col">GF</th> <th aria-label="Goals Against" class="poptip center" data-over-header="Home" data-stat="home_goals_against" data-tip="&lt;strong&gt;Goals Against&lt;/strong&gt;&lt;br&gt;Goals Against" scope="col">GA</th> <th aria-label="Goal Difference" class="poptip center" data-over-header="Home" data-stat="home_goal_diff" data-tip="&lt;strong&gt;Goal Difference&lt;/strong&gt;&lt;br&gt;Goal Difference" scope="col">GD</th> <th aria-label="Points" class="poptip center" data-over-header="Home" data-stat="home_points" data-tip="&lt;strong&gt;Points&lt;/strong&gt;&lt;br&gt;Most leagues are ordered by points.&lt;br&gt;Three for a win and one for a draw." scope="col">Pts</th> <th aria-label="Points/Match" class="poptip center" data-over-header="Home" data-stat="home_points_avg" data-tip="&lt;strong&gt;Points/Match&lt;/strong&gt;&lt;br&gt;Points per Match Played" scope="col">Pts/MP</th> <th aria-label="xG" class="poptip center" data-filter="1" data-name="xG" data-over-header="Home" data-stat="home_xg_for" data-tip="&lt;strong&gt;Expected Goals&lt;/strong&gt;&lt;br&gt;xG totals include penalty kicks, but do not include penalty shootouts (unless otherwise noted).&lt;br&gt;Provided by Opta.&lt;br&gt;An underline indicates there is a match that is missing data, but will be updated when available." scope="col">xG</th> <th aria-label="xG Allowed" class="poptip sort_default_asc center" data-over-header="Home" data-stat="home_xg_against" data-tip="&lt;strong&gt;xG Allowed&lt;/strong&gt;&lt;br&gt;&lt;strong&gt;Expected Goals Allowed&lt;/strong&gt;&lt;br&gt;xG totals include penalty kicks, but do not include penalty shootouts (unless otherwise noted).&lt;br&gt;Provided by Opta.&lt;br&gt;An underline i ...

# %%
standings_table = soup.select('table.stats_table')[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_81148\1600810149.py in <module>
# ----> 1 standings_table = soup.select('table.stats_table')[0]
#
# IndexError: list index out of range

# %%
type(standings_table)
# Out:
# bs4.element.Tag

# %%
links = standings_table.find_all('a')

# %%
print(type(links))
print(type(links[0]))
print(links[0])
# Out:
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.Tag'>
# <a href="/en/squads/b8fd03ef/Manchester-City-Stats">Manchester City</a>

# %%
links = [l.get("href") for l in links] # it finds the value of of the hfref-property

# %%
links =  [l for l in links if '/squads/' in l]

# %%
links
# Out:
# ['/en/squads/b8fd03ef/Manchester-City-Stats',
#  '/en/squads/822bd0ba/Liverpool-Stats',
#  '/en/squads/18bb7c10/Arsenal-Stats',
#  '/en/squads/361ca564/Tottenham-Hotspur-Stats',
#  '/en/squads/8602292d/Aston-Villa-Stats',
#  '/en/squads/19538871/Manchester-United-Stats',
#  '/en/squads/b2b47a98/Newcastle-United-Stats',
#  '/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats',
#  '/en/squads/7c21e445/West-Ham-United-Stats',
#  '/en/squads/cff3d9bb/Chelsea-Stats',
#  '/en/squads/cd051869/Brentford-Stats',
#  '/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats',
#  '/en/squads/47c64c55/Crystal-Palace-Stats',
#  '/en/squads/e4a775cb/Nottingham-Forest-Stats',
#  '/en/squads/fd962109/Fulham-Stats',
#  '/en/squads/4ba7cbea/Bournemouth-Stats',
#  '/en/squads/e297cd13/Luton-Town-Stats',
#  '/en/squads/1df6b87e/Sheffield-United-Stats',
#  '/en/squads/d3fd31cc/Everton-Stats',
#  '/en/squads/943e8050/Burnley-Stats']

# %%
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
print(type(team_urls))   # the type "list" means that this object can be iterated
# Out:
# <class 'list'>

# %%
team_urls
# Out:
# ['https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats',
#  'https://fbref.com/en/squads/822bd0ba/Liverpool-Stats',
#  'https://fbref.com/en/squads/18bb7c10/Arsenal-Stats',
#  'https://fbref.com/en/squads/361ca564/Tottenham-Hotspur-Stats',
#  'https://fbref.com/en/squads/8602292d/Aston-Villa-Stats',
#  'https://fbref.com/en/squads/19538871/Manchester-United-Stats',
#  'https://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats',
#  'https://fbref.com/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats',
#  'https://fbref.com/en/squads/7c21e445/West-Ham-United-Stats',
#  'https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats',
#  'https://fbref.com/en/squads/cd051869/Brentford-Stats',
#  'https://fbref.com/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats',
#  'https://fbref.com/en/squads/47c64c55/Crystal-Palace-Stats',
#  'https://fbref.com/en/squads/e4a775cb/Nottingham-Forest-Stats',
#  'https://fbref.com/en/squads/fd962109/Fulham-Stats',
#  'https://fbref.com/en/squads/4ba7cbea/Bournemouth-Stats',
#  'https://fbref.com/en/squads/e297cd13/Luton-Town-Stats',
#  'https://fbref.com/en/squads/1df6b87e/Sheffield-United-Stats',
#  'https://fbref.com/en/squads/d3fd31cc/Everton-Stats',
#  'https://fbref.com/en/squads/943e8050/Burnley-Stats']

# %% [markdown]
# # Let's explore one link

# %% [markdown]
# Since any list can be iterated we need to get access to one link and then create a loop

# %% [markdown]
# So, for example, let's take the first one (but it can be any link)

# %%
team_url = team_urls[0]

# %%
data = requests.get(team_url)

# %%
matches = pd.read_html(data.text, match = 'Scores & Fixtures')[0] #We convert html document into Pandas DataFrame

# %%
matches.head() #Just checking
# Out:
#          Date   Time              Comp                Round  Day    Venue  \
# 0  2023-08-06  16:00  Community Shield  FA Community Shield  Sun  Neutral
# 1  2023-08-11  20:00    Premier League          Matchweek 1  Fri     Away
# 2  2023-08-16  22:00         Super Cup       UEFA Super Cup  Wed     Home
# 3  2023-08-19  20:00    Premier League          Matchweek 2  Sat     Home
# 4  2023-08-27  14:00    Premier League          Matchweek 3  Sun     Away
#
#   Result     GF     GA       Opponent   xG  xGA  Poss  Attendance  \
# 0      D  1 (1)  1 (4)        Arsenal  NaN  NaN  55.0     81145.0
# 1      W      3      0        Burnley  1.9  0.3  65.0     21572.0
# 2      D  1 (5)  1 (4)     es Sevilla  NaN  NaN  74.0         NaN
# 3      W      1      0  Newcastle Utd  1.0  0.3  59.0         NaN
# 4      W      2      1  Sheffield Utd  3.5  0.7  79.0     31336.0
#
#            Captain Formation            Referee  Match Report  \
# 0      Kyle Walker   4-2-3-1     Stuart Attwell  Match Report
# 1  Kevin De Bruyne   4-2-3-1       Craig Pawson  Match Report
# 2      Kyle Walker   4-2-3-1  François Letexier  Match Report
# 3      Kyle Walker   4-2-3-1       Robert Jones  Match Report
# 4      Kyle Walker   4-2-3-1     Jarred Gillett  Match Report
#
#                                                Notes
# 0  Arsenal won on penalty kicks following normal ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %% [markdown]
# We're missing some data about kicks, results

# %%
soup = BeautifulSoup(data.text)

# %%
links = soup.find_all('a')
links = [l.get('href') for l in links]
links = [l for l in links if l and 'all_comps/shooting/' in l] # That is the link with the table that contains information about kicks and results

# %%
links #Just checking
# Out:
# ['/en/squads/b8fd03ef/2023-2024/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions',
#  '/en/squads/b8fd03ef/2023-2024/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions',
#  '/en/squads/b8fd03ef/2023-2024/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions',
#  '/en/squads/b8fd03ef/2023-2024/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions']

# %%
data = requests.get(f'https://fbref.com{links[0]}') # since all links are the same we take the first one

# %%
shooting = pd.read_html(data.text, match = 'Shooting')[0] # we add [0] because data.text is just a string

# %%
shooting.head()
# Out:
#   For Manchester City                                                     \
#                  Date   Time              Comp                Round  Day
# 0          2023-08-06  16:00  Community Shield  FA Community Shield  Sun
# 1          2023-08-11  20:00    Premier League          Matchweek 1  Fri
# 2          2023-08-16  22:00         Super Cup       UEFA Super Cup  Wed
# 3          2023-08-19  20:00    Premier League          Matchweek 2  Sat
# 4          2023-08-27  14:00    Premier League          Matchweek 3  Sun
#
#                                                 ... Standard                \
#      Venue Result     GF     GA       Opponent  ...     Dist   FK PK PKatt
# 0  Neutral      D  1 (1)  1 (4)        Arsenal  ...      NaN  NaN  0     0
# 1     Away      W      3      0        Burnley  ...     13.9  0.0  0     0
# 2     Home      D  1 (5)  1 (4)     es Sevilla  ...      NaN  NaN  0     0
# 3     Home      W      1      0  Newcastle Utd  ...     17.9  0.0  0     0
# 4     Away      W      2      1  Sheffield Utd  ...     17.3  2.0  0     1
#
#   Expected                           Unnamed: 25_level_0
#         xG npxG npxG/Sh G-xG np:G-xG        Match Report
# 0      NaN  NaN     NaN  NaN     NaN        Match Report
# 1      1.9  1.9    0.12  1.1     1.1        Match Report
# 2      NaN  NaN     NaN  NaN     NaN        Match Report
# 3      1.0  1.0    0.07  0.0     0.0        Match Report
# 4      3.5  2.8    0.10 -1.5    -0.8        Match Report
#
# [5 rows x 26 columns]

# %%
shooting.columns = shooting.columns.droplevel()   # multilevel index isn't necessary in our case, so we can drop it

# %%
shooting.head()
# Out:
#          Date   Time              Comp                Round  Day    Venue  \
# 0  2023-08-06  16:00  Community Shield  FA Community Shield  Sun  Neutral
# 1  2023-08-11  20:00    Premier League          Matchweek 1  Fri     Away
# 2  2023-08-16  22:00         Super Cup       UEFA Super Cup  Wed     Home
# 3  2023-08-19  20:00    Premier League          Matchweek 2  Sat     Home
# 4  2023-08-27  14:00    Premier League          Matchweek 3  Sun     Away
#
#   Result     GF     GA       Opponent  ...  Dist   FK  PK  PKatt   xG  npxG  \
# 0      D  1 (1)  1 (4)        Arsenal  ...   NaN  NaN   0      0  NaN   NaN
# 1      W      3      0        Burnley  ...  13.9  0.0   0      0  1.9   1.9
# 2      D  1 (5)  1 (4)     es Sevilla  ...   NaN  NaN   0      0  NaN   NaN
# 3      W      1      0  Newcastle Utd  ...  17.9  0.0   0      0  1.0   1.0
# 4      W      2      1  Sheffield Utd  ...  17.3  2.0   0      1  3.5   2.8
#
#    npxG/Sh  G-xG  np:G-xG  Match Report
# 0      NaN   NaN      NaN  Match Report
# 1     0.12   1.1      1.1  Match Report
# 2      NaN   NaN      NaN  Match Report
# 3     0.07   0.0      0.0  Match Report
# 4     0.10  -1.5     -0.8  Match Report
#
# [5 rows x 26 columns]

# %%
team_data = matches.merge(shooting[['Date', 'Sh', 'SoT', 'Dist', 'FK', 'PK', 'PKatt']], on = 'Date') #merging two tables into one

# %%
team_data.head()
# Out:
#          Date   Time              Comp                Round  Day    Venue  \
# 0  2023-08-06  16:00  Community Shield  FA Community Shield  Sun  Neutral
# 1  2023-08-11  20:00    Premier League          Matchweek 1  Fri     Away
# 2  2023-08-16  22:00         Super Cup       UEFA Super Cup  Wed     Home
# 3  2023-08-19  20:00    Premier League          Matchweek 2  Sat     Home
# 4  2023-08-27  14:00    Premier League          Matchweek 3  Sun     Away
#
#   Result     GF     GA       Opponent  ...  Formation            Referee  \
# 0      D  1 (1)  1 (4)        Arsenal  ...    4-2-3-1     Stuart Attwell
# 1      W      3      0        Burnley  ...    4-2-3-1       Craig Pawson
# 2      D  1 (5)  1 (4)     es Sevilla  ...    4-2-3-1  François Letexier
# 3      W      1      0  Newcastle Utd  ...    4-2-3-1       Robert Jones
# 4      W      2      1  Sheffield Utd  ...    4-2-3-1     Jarred Gillett
#
#    Match Report                                              Notes  Sh SoT  \
# 0  Match Report  Arsenal won on penalty kicks following normal ...   8   4
# 1  Match Report                                                NaN  17   8
# 2  Match Report                                                NaN  23   7
# 3  Match Report                                                NaN  14   4
# 4  Match Report                                                NaN  29   9
#
#    Dist   FK PK  PKatt
# 0   NaN  NaN  0      0
# 1  13.9  0.0  0      0
# 2   NaN  NaN  0      0
# 3  17.9  0.0  0      0
# 4  17.3  2.0  0      1
#
# [5 rows x 25 columns]

# %%
print(matches.shape)
print(shooting.shape)
print(team_data.shape)
# Out:
# (47, 19)
# (20, 26)
# (19, 25)

# %% [markdown]
# # Let's start

# %% [markdown]
# Now we need just to create a loop and collect information about all teams in the table

# %%
years = list(range(2023, 2020, -1))

# %%
all_matches = [] # it will contain several DataFrames and each DataFrame is going to contain the match log for one team in one season

# %%
standings_url = 'https://fbref.com/en/comps/9/Premier-League-Stats'

# %%
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]
    
    links = [l.get("href") for l in standings_table.find_all('a')]
    links =  [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links] # we get all links, related to diffrent teams
    
    previous_season = soup.select('a.prev')[0].get('href')
    standings_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split('/')[-1].replace('-Stats', '').replace('-','')
        
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match = 'Scores & Fixtures')[0]
        
        soup = BeautifulSoup(data.text)
        links = [l.get('href') for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        data = requests.get(f'https://fbref.com{links[0]}')
        shooting = pd.read_html(data.text, match = 'Shooting')[0]
        shooting.columns = shooting.columns.droplevel()
        
        try:
            team_data = matches.merge(shooting[['Date', 'Sh', 'SoT', 'Dist', 'FK', 'PK', 'PKatt']], on = 'Date')
        except ValueError:
            continue
            
        team_data = team_data[team_data['Comp'] == "Premier League"]
        team_data['Season'] = year
        team_data['Team'] = team_name
        all_matches.append(team_data)
        
        time.sleep(3) # in order not to make a lot of requests very quickly and slow down websites, I don't wanna be banned

# %%
match_df = pd.concat(all_matches)

# %% [markdown]
# Next two section were created to show what was done in the previous section (to get better understanding)

# %%
data = requests.get('https://fbref.com/en/comps/9/Premier-League-Stats')
soup = BeautifulSoup(data.text)
print(soup.select('a.prev'))
print("Type of the element: ", type(soup.select('a.prev')))
print()
print(soup.select('a.prev')[0])
print("Type of the element: ", type(soup.select('a.prev')[0]))
print()
print(soup.select('a.prev')[0].get('href'))
print("Type of the element: ", type(soup.select('a.prev')[0].get('href')))
# Out:
# [<a class="button2 prev" href="/en/comps/9/2022-2023/2022-2023-Premier-League-Stats">Previous Season</a>]
# Type of the element:  <class 'bs4.element.ResultSet'>
#
# <a class="button2 prev" href="/en/comps/9/2022-2023/2022-2023-Premier-League-Stats">Previous Season</a>
# Type of the element:  <class 'bs4.element.Tag'>
#
# /en/comps/9/2022-2023/2022-2023-Premier-League-Stats
# Type of the element:  <class 'str'>

# %%
standings_url = 'https://fbref.com/en/comps/9/Premier-League-Stats'
data = requests.get(standings_url)
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[0]

# %%
match_df
# Out:
#           Date   Time            Comp         Round  Day Venue Result GF GA  \
# 1   2023-08-12  12:30  Premier League   Matchweek 1  Sat  Home      W  2  1
# 2   2023-08-21  20:00  Premier League   Matchweek 2  Mon  Away      W  1  0
# 3   2023-08-26  15:00  Premier League   Matchweek 3  Sat  Home      D  2  2
# 4   2023-09-03  16:30  Premier League   Matchweek 4  Sun  Home      W  3  1
# 5   2023-09-17  16:30  Premier League   Matchweek 5  Sun  Away      W  1  0
# ..         ...    ...             ...           ...  ...   ...    ... .. ..
# 38  2022-04-30  15:00  Premier League  Matchweek 35  Sat  Away      L  0  2
# 39  2022-05-08  14:00  Premier League  Matchweek 36  Sun  Home      L  0  4
# 40  2022-05-11  19:45  Premier League  Matchweek 21  Wed  Away      L  0  3
# 41  2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away      D  1  1
# 42  2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      L  0  5
#
#            Opponent  ...  Match Report  Notes    Sh  SoT  Dist   FK PK PKatt  \
# 1   Nott'ham Forest  ...  Match Report    NaN  15.0  7.0  19.1  0.0  0     0
# 2    Crystal Palace  ...  Match Report    NaN  13.0  2.0  16.4  0.0  1     1
# 3            Fulham  ...  Match Report    NaN  18.0  9.0  13.8  0.0  1     1
# 4    Manchester Utd  ...  Match Report    NaN  17.0  5.0  15.0  0.0  0     0
# 5           Everton  ...  Match Report    NaN  13.0  4.0  17.4  0.0  0     0
# ..              ...  ...           ...    ...   ...  ...   ...  ... ..   ...
# 38      Aston Villa  ...  Match Report    NaN   9.0  3.0  21.6  0.0  0     0
# 39         West Ham  ...  Match Report    NaN   8.0  2.0  22.2  1.0  0     0
# 40   Leicester City  ...  Match Report    NaN   9.0  5.0  17.0  0.0  0     0
# 41           Wolves  ...  Match Report    NaN  11.0  2.0  14.4  0.0  0     0
# 42        Tottenham  ...  Match Report    NaN   9.0  0.0  18.6  0.0  0     0
#
#    Season         Team
# 1    2023      Arsenal
# 2    2023      Arsenal
# 3    2023      Arsenal
# 4    2023      Arsenal
# 5    2023      Arsenal
# ..    ...          ...
# 38   2021  NorwichCity
# 39   2021  NorwichCity
# 40   2021  NorwichCity
# 41   2021  NorwichCity
# 42   2021  NorwichCity
#
# [1780 rows x 27 columns]

# %%
match_df.columns = [c.lower() for c in match_df.columns] # it's easier to work with lowercase

# %%
match_df.head()
# Out:
#          date   time            comp        round  day venue result gf ga  \
# 1  2023-08-12  12:30  Premier League  Matchweek 1  Sat  Home      W  2  1
# 2  2023-08-21  20:00  Premier League  Matchweek 2  Mon  Away      W  1  0
# 3  2023-08-26  15:00  Premier League  Matchweek 3  Sat  Home      D  2  2
# 4  2023-09-03  16:30  Premier League  Matchweek 4  Sun  Home      W  3  1
# 5  2023-09-17  16:30  Premier League  Matchweek 5  Sun  Away      W  1  0
#
#           opponent  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 1  Nott'ham Forest  ...  Match Report    NaN  15.0  7.0  19.1  0.0  0     0
# 2   Crystal Palace  ...  Match Report    NaN  13.0  2.0  16.4  0.0  1     1
# 3           Fulham  ...  Match Report    NaN  18.0  9.0  13.8  0.0  1     1
# 4   Manchester Utd  ...  Match Report    NaN  17.0  5.0  15.0  0.0  0     0
# 5          Everton  ...  Match Report    NaN  13.0  4.0  17.4  0.0  0     0
#
#   season     team
# 1   2023  Arsenal
# 2   2023  Arsenal
# 3   2023  Arsenal
# 4   2023  Arsenal
# 5   2023  Arsenal
#
# [5 rows x 27 columns]

# %%
print(match_df.shape)
# Out:
# (1780, 27)

# %% [markdown]
# With 20 teams in the Premier League, each team ends the season having played 38 games. 19 are played at home and the other half are away fixtures. In total, 380 Premier League matches are played each season (we have 3 seasons: 2021, 2022, 2023).

# %%
print('The number of matches we should have:', 20 * 38 * 3)
# Out:
# The number of matches we should have: 2280

# %% [markdown]
# But we have 1760 matches

# %%
match_df['team'].value_counts() # How many matches we have for each team in our data
# Out:
# ManchesterCity            88
# WestHamUnited             88
# Everton                   88
# Liverpool                 88
# WolverhamptonWanderers    88
# Brentford                 88
# Chelsea                   88
# CrystalPalace             88
# BrightonandHoveAlbion     88
# ManchesterUnited          88
# AstonVilla                88
# TottenhamHotspur          88
# NewcastleUnited           88
# Arsenal                   88
# Southampton               76
# LeicesterCity             76
# LeedsUnited               76
# NottinghamForest          50
# Fulham                    50
# Bournemouth               50
# Burnley                   50
# Watford                   38
# NorwichCity               38
# SheffieldUnited           12
# LutonTown                 12
# Name: team, dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
match_df.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf               object
# ga               object
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes            object
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %% [markdown]
# Since ML-algorythms can't work with data that is an object

# %%
match_df['date'] = pd.to_datetime(match_df['date'])

# %%
match_df.head()
# Out:
#         date   time            comp        round  day venue result gf ga  \
# 1 2023-08-12  12:30  Premier League  Matchweek 1  Sat  Home      W  2  1
# 2 2023-08-21  20:00  Premier League  Matchweek 2  Mon  Away      W  1  0
# 3 2023-08-26  15:00  Premier League  Matchweek 3  Sat  Home      D  2  2
# 4 2023-09-03  16:30  Premier League  Matchweek 4  Sun  Home      W  3  1
# 5 2023-09-17  16:30  Premier League  Matchweek 5  Sun  Away      W  1  0
#
#           opponent  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 1  Nott'ham Forest  ...  Match Report    NaN  15.0  7.0  19.1  0.0  0     0
# 2   Crystal Palace  ...  Match Report    NaN  13.0  2.0  16.4  0.0  1     1
# 3           Fulham  ...  Match Report    NaN  18.0  9.0  13.8  0.0  1     1
# 4   Manchester Utd  ...  Match Report    NaN  17.0  5.0  15.0  0.0  0     0
# 5          Everton  ...  Match Report    NaN  13.0  4.0  17.4  0.0  0     0
#
#   season     team
# 1   2023  Arsenal
# 2   2023  Arsenal
# 3   2023  Arsenal
# 4   2023  Arsenal
# 5   2023  Arsenal
#
# [5 rows x 27 columns]

# %%
match_df.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                      object
# ga                      object
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                   object
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                       int64
# pkatt                    int64
# season                   int64
# team                    object
# dtype: object

# %%
match_df['venue'].value_counts() # This is very important predictor and we need it to be int-type or category
# Out:
# Home    890
# Away    890
# Name: venue, dtype: int64

# %%
matches = pd.get_dummies(match_df, columns=['venue'], drop_first = True, prefix=None) # 1 - Home, 0 - Away

# %%
mathces = matches.rename(columns = {'venue_Home':'home'},inplace = True)

# %%
matches.head()
# Out:
#         date   time            comp        round  day result gf ga  \
# 1 2023-08-12  12:30  Premier League  Matchweek 1  Sat      W  2  1
# 2 2023-08-21  20:00  Premier League  Matchweek 2  Mon      W  1  0
# 3 2023-08-26  15:00  Premier League  Matchweek 3  Sat      D  2  2
# 4 2023-09-03  16:30  Premier League  Matchweek 4  Sun      W  3  1
# 5 2023-09-17  16:30  Premier League  Matchweek 5  Sun      W  1  0
#
#           opponent   xg  ...  notes    sh  sot  dist   fk pk pkatt season  \
# 1  Nott'ham Forest  0.8  ...    NaN  15.0  7.0  19.1  0.0  0     0   2023
# 2   Crystal Palace  2.0  ...    NaN  13.0  2.0  16.4  0.0  1     1   2023
# 3           Fulham  3.2  ...    NaN  18.0  9.0  13.8  0.0  1     1   2023
# 4   Manchester Utd  2.3  ...    NaN  17.0  5.0  15.0  0.0  0     0   2023
# 5          Everton  1.0  ...    NaN  13.0  4.0  17.4  0.0  0     0   2023
#
#       team  home
# 1  Arsenal     1
# 2  Arsenal     0
# 3  Arsenal     1
# 4  Arsenal     1
# 5  Arsenal     0
#
# [5 rows x 27 columns]

# %%
print(type(matches['time'].str.replace(':.+', "", regex=True).astype('int')))
print(matches['time'].str.replace(':.+', "", regex=True).astype('int'))
# Out:
# <class 'pandas.core.series.Series'>
# 1     12
# 2     20
# 3     15
# 4     16
# 5     16
#       ..
# 38    15
# 39    14
# 40    19
# 41    14
# 42    16
# Name: time, Length: 1780, dtype: int32

# %%
matches['hour'] = matches['time'].str.replace(':.+', "", regex=True).astype('int') # we add a columns "hour" that shows us what time a match started

# %%
matches.head()
# Out:
#         date   time            comp        round  day result gf ga  \
# 1 2023-08-12  12:30  Premier League  Matchweek 1  Sat      W  2  1
# 2 2023-08-21  20:00  Premier League  Matchweek 2  Mon      W  1  0
# 3 2023-08-26  15:00  Premier League  Matchweek 3  Sat      D  2  2
# 4 2023-09-03  16:30  Premier League  Matchweek 4  Sun      W  3  1
# 5 2023-09-17  16:30  Premier League  Matchweek 5  Sun      W  1  0
#
#           opponent   xg  ...    sh  sot  dist   fk pk pkatt season     team  \
# 1  Nott'ham Forest  0.8  ...  15.0  7.0  19.1  0.0  0     0   2023  Arsenal
# 2   Crystal Palace  2.0  ...  13.0  2.0  16.4  0.0  1     1   2023  Arsenal
# 3           Fulham  3.2  ...  18.0  9.0  13.8  0.0  1     1   2023  Arsenal
# 4   Manchester Utd  2.3  ...  17.0  5.0  15.0  0.0  0     0   2023  Arsenal
# 5          Everton  1.0  ...  13.0  4.0  17.4  0.0  0     0   2023  Arsenal
#
#    home  hour
# 1     1    12
# 2     0    20
# 3     1    15
# 4     1    16
# 5     0    16
#
# [5 rows x 28 columns]

# %%
matches['day_code'] = matches['date'].dt.dayofweek # we try to get a number for each day of the week (Monday - 0, ..., Sunday - 6)

# %%
matches["opp_code"] = matches['opponent'].astype('category').cat.codes

# %% [markdown]
# Since we want to predict if a team wins or not we can encode Loses and Draws as 0

# %%
matches['target'] = (matches['result'] == 'W').astype("int") # We convert Wins to True and then to 1, using astype(int)

# %%
matches.head()
# Out:
#         date   time            comp        round  day result gf ga  \
# 1 2023-08-12  12:30  Premier League  Matchweek 1  Sat      W  2  1
# 2 2023-08-21  20:00  Premier League  Matchweek 2  Mon      W  1  0
# 3 2023-08-26  15:00  Premier League  Matchweek 3  Sat      D  2  2
# 4 2023-09-03  16:30  Premier League  Matchweek 4  Sun      W  3  1
# 5 2023-09-17  16:30  Premier League  Matchweek 5  Sun      W  1  0
#
#           opponent   xg  ...  dist   fk  pk pkatt season     team home hour  \
# 1  Nott'ham Forest  0.8  ...  19.1  0.0   0     0   2023  Arsenal    1   12
# 2   Crystal Palace  2.0  ...  16.4  0.0   1     1   2023  Arsenal    0   20
# 3           Fulham  3.2  ...  13.8  0.0   1     1   2023  Arsenal    1   15
# 4   Manchester Utd  2.3  ...  15.0  0.0   0     0   2023  Arsenal    1   16
# 5          Everton  1.0  ...  17.4  0.0   0     0   2023  Arsenal    0   16
#
#    day_code  target
# 1         5       1
# 2         0       1
# 3         5       0
# 4         6       1
# 5         6       1
#
# [5 rows x 30 columns]

# %% [markdown]
# # Visualization and Data Analysis

# %% [markdown]
# # Training and Validation

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, precision_score, recall_score
from sklearn.model_selection import GridSearchCV

# %%
train = matches[matches['date'] < "2023-01-01"]
test = matches[matches['date'] > "2023-01-01"]

# %%
print('Train-test proportion:', round(len(train)/len(matches),2), round(len(test)/len(matches),2))
# Out:
# Train-test proportion: 0.61 0.39

# %%
predictors = ['home', 'opp_code', 'day_code', 'hour']

# %%
param_grid = {'n_estimators': [64, 100, 120], 'max_features': [2,3,4], 'min_samples_split': [2, 5, 10], 'max_depth':[3,5,7]}

# %%
rfc = RandomForestClassifier(random_state=42)

# %%
grid = GridSearchCV(rfc, param_grid)

# %% [markdown]
# Classification accuracy is the most-used metric for evaluating classification models.
#
# The reason for its wide use is because it is easy to calculate, easy to interpret, and is a single number to summarize the model’s capability, but Accuracy is not a good metric for imbalanced data

# %%
grid.fit(train[predictors], train["target"])
# Out:
# GridSearchCV(estimator=RandomForestClassifier(random_state=42),
#              param_grid={'max_depth': [3, 5, 7], 'max_features': [2, 3, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [64, 100, 120]})

# %%
grid.best_params_
# Out:
# {'max_depth': 5,
#  'max_features': 4,
#  'min_samples_split': 10,
#  'n_estimators': 100}

# %%
rfc = RandomForestClassifier(n_estimators=100, max_features=4, max_depth=5, min_samples_split=10, random_state = 42)

# %%
rfc.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(max_depth=5, max_features=4, min_samples_split=10,
#                        random_state=42)

# %%
preds = rfc.predict(test[predictors])

# %%
accuracy_score(test['target'], preds)
# Out:
# 0.6293604651162791

# %%
combined = pd.DataFrame(dict(actual = test['target'], prediction = preds))

# %%
pd.crosstab(index=combined['actual'], columns = combined['prediction'])
# Out:
# prediction    0   1
# actual
# 0           367  52
# 1           203  66

# %%
print(precision_score(test['target'], preds))
print(recall_score(test['target'], preds))
# Out:
# 0.559322033898305
# 0.24535315985130113

# %% [markdown]
# We want to compute rolling averages for team perfomance, how this team did in the past few games, how many shots they had, how many goals were scored against them
#
# It is done to to discover the trend, a rolling average uses smaller parts of the data. For instance, you might use the numbers collected over the last 30 days and find out their average. Then, the average rolls or moves for each new period. Making these calculations for every 30 day period allows professionals to discover the way the average changes as time moves forward.

# %%
grouped_matches = matches.groupby('team') # one DataFrame for every squad in our data

# %%
type(grouped_matches)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
group = grouped_matches.get_group("Arsenal") # it will help us to analise their statistic (for exmaple, if a team lost 4 matches in row, it is highly likely that it will lost again because all players might not be in a good shape)

# %%
group.head()
# Out:
#         date   time            comp        round  day result gf ga  \
# 1 2023-08-12  12:30  Premier League  Matchweek 1  Sat      W  2  1
# 2 2023-08-21  20:00  Premier League  Matchweek 2  Mon      W  1  0
# 3 2023-08-26  15:00  Premier League  Matchweek 3  Sat      D  2  2
# 4 2023-09-03  16:30  Premier League  Matchweek 4  Sun      W  3  1
# 5 2023-09-17  16:30  Premier League  Matchweek 5  Sun      W  1  0
#
#           opponent   xg  ...   fk  pk  pkatt season     team home hour  \
# 1  Nott'ham Forest  0.8  ...  0.0   0      0   2023  Arsenal    1   12
# 2   Crystal Palace  2.0  ...  0.0   1      1   2023  Arsenal    0   20
# 3           Fulham  3.2  ...  0.0   1      1   2023  Arsenal    1   15
# 4   Manchester Utd  2.3  ...  0.0   0      0   2023  Arsenal    1   16
# 5          Everton  1.0  ...  0.0   0      0   2023  Arsenal    0   16
#
#   day_code  target  opp_code
# 1        5       1        18
# 2        0       1         7
# 3        5       0         9
# 4        6       1        15
# 5        6       1         8
#
# [5 rows x 31 columns]

# %% [markdown]
# We should create a function that takes a group, a set of columns that we want to compute rolling averages for and then it'll take a new set of columns that we want to assign rolling averages to

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values('date')
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats # extra columns that describe what happened in the previous 3 matches
    group = group.dropna(subset = new_cols) # we drop any missing values (any rows that have missing values)
    return group

# %%
cols = ['gf', 'ga', 'sh', 'sot', 'dist', 'fk', 'pk', 'pkatt']
new_cols = [f"{c}_rolling" for c in cols]

# %% [markdown]
# gf - goals for
#
# ga - goals agains
#
# sh - shots
#
# sot - shots on target
#
# dist - total distance each shot travelled
#
# fk - free kicks
#
# pk - penalty kicks
#
# pka - penalty kick attempts

# %%
rolling_averages(group, cols, new_cols).head() # we added the columns that describe what happened in the previous 3 matches
# Out:
#         date   time            comp        round  day result gf ga  \
# 4 2021-09-11  15:00  Premier League  Matchweek 4  Sat      W  1  0
# 5 2021-09-18  15:00  Premier League  Matchweek 5  Sat      W  1  0
# 7 2021-09-26  16:30  Premier League  Matchweek 6  Sun      W  3  1
# 8 2021-10-02  17:30  Premier League  Matchweek 7  Sat      D  0  0
# 9 2021-10-18  20:00  Premier League  Matchweek 8  Mon      D  2  2
#
#          opponent   xg  ...  target  opp_code  gf_rolling ga_rolling  \
# 4    Norwich City  2.7  ...       1        17    0.000000   3.000000
# 5         Burnley  1.1  ...       1         5    0.333333   2.333333
# 7       Tottenham  1.1  ...       1        21    0.666667   1.666667
# 8        Brighton  0.4  ...       0         4    1.666667   0.333333
# 9  Crystal Palace  1.7  ...       0         7    1.333333   0.333333
#
#   sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 4   9.666667    2.333333    14.833333   0.333333         0.0            0.0
# 5  12.333333    3.000000    14.133333   0.333333         0.0            0.0
# 7  14.666667    3.000000    14.800000   0.666667         0.0            0.0
# 8  18.333333    5.333333    18.433333   0.666667         0.0            0.0
# 9  11.000000    4.000000    19.833333   0.666667         0.0            0.0
#
# [5 rows x 39 columns]

# %%
matches_rolling = grouped_matches.apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
grouped_matches.apply(lambda x: rolling_averages(x, cols, new_cols)).head()
# Out:
#                 date   time            comp        round  day result gf ga  \
# team
# Arsenal 4 2021-09-11  15:00  Premier League  Matchweek 4  Sat      W  1  0
#         5 2021-09-18  15:00  Premier League  Matchweek 5  Sat      W  1  0
#         7 2021-09-26  16:30  Premier League  Matchweek 6  Sun      W  3  1
#         8 2021-10-02  17:30  Premier League  Matchweek 7  Sat      D  0  0
#         9 2021-10-18  20:00  Premier League  Matchweek 8  Mon      D  2  2
#
#                  opponent   xg  ...  target  opp_code  gf_rolling ga_rolling  \
# team                            ...
# Arsenal 4    Norwich City  2.7  ...       1        17    0.000000   3.000000
#         5         Burnley  1.1  ...       1         5    0.333333   2.333333
#         7       Tottenham  1.1  ...       1        21    0.666667   1.666667
#         8        Brighton  0.4  ...       0         4    1.666667   0.333333
#         9  Crystal Palace  1.7  ...       0         7    1.333333   0.333333
#
#           sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  \
# team
# Arsenal 4   9.666667    2.333333    14.833333   0.333333         0.0
#         5  12.333333    3.000000    14.133333   0.333333         0.0
#         7  14.666667    3.000000    14.800000   0.666667         0.0
#         8  18.333333    5.333333    18.433333   0.666667         0.0
#         9  11.000000    4.000000    19.833333   0.666667         0.0
#
#            pkatt_rolling
# team
# Arsenal 4            0.0
#         5            0.0
#         7            0.0
#         8            0.0
#         9            0.0
#
# [5 rows x 39 columns]

# %%
matches_rolling = matches_rolling.droplevel('team') # we drop extra index level (team)

# %%
matches_rolling
# Out:
#          date   time            comp         round  day result   gf   ga  \
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat      W    1    0
# 5  2021-09-18  15:00  Premier League   Matchweek 5  Sat      W    1    0
# 7  2021-09-26  16:30  Premier League   Matchweek 6  Sun      W    3    1
# 8  2021-10-02  17:30  Premier League   Matchweek 7  Sat      D    0    0
# 9  2021-10-18  20:00  Premier League   Matchweek 8  Mon      D    2    2
# ..        ...    ...             ...           ...  ...    ...  ...  ...
# 10 2023-10-21  15:00  Premier League   Matchweek 9  Sat      W  2.0  1.0
# 11 2023-10-28  17:30  Premier League  Matchweek 10  Sat      D  2.0  2.0
# 12 2023-11-04  15:00  Premier League  Matchweek 11  Sat      L  1.0  2.0
# 13 2023-11-11  12:30  Premier League  Matchweek 12  Sat      W  2.0  1.0
# 14 2023-11-27  20:00  Premier League  Matchweek 13  Mon      L  2.0  3.0
#
#           opponent   xg  ...  target  opp_code  gf_rolling ga_rolling  \
# 4     Norwich City  2.7  ...       1        17    0.000000   3.000000
# 5          Burnley  1.1  ...       1         5    0.333333   2.333333
# 7        Tottenham  1.1  ...       1        21    0.666667   1.666667
# 8         Brighton  0.4  ...       0         4    1.666667   0.333333
# 9   Crystal Palace  1.7  ...       0         7    1.333333   0.333333
# ..             ...  ...  ...     ...       ...         ...        ...
# 10     Bournemouth  2.4  ...       1         2    1.333333   1.000000
# 11   Newcastle Utd  0.9  ...       0        16    1.666667   1.000000
# 12   Sheffield Utd  1.2  ...       0        19    1.666667   1.333333
# 13       Tottenham  2.1  ...       1        21    1.666667   1.666667
# 14          Fulham  1.4  ...       0         9    1.666667   1.666667
#
#    sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 4    9.666667    2.333333    14.833333   0.333333         0.0            0.0
# 5   12.333333    3.000000    14.133333   0.333333         0.0            0.0
# 7   14.666667    3.000000    14.800000   0.666667         0.0            0.0
# 8   18.333333    5.333333    18.433333   0.666667         0.0            0.0
# 9   11.000000    4.000000    19.833333   0.666667         0.0            0.0
# ..        ...         ...          ...        ...         ...            ...
# 10   4.666667    2.333333    11.466667   0.000000         0.0            0.0
# 11  10.666667    3.666667    14.533333   0.000000         0.0            0.0
# 12  13.333333    5.333333    16.466667   0.333333         0.0            0.0
# 13  14.000000    5.333333    16.966667   0.666667         0.0            0.0
# 14  12.666667    4.333333    17.733333   0.666667         0.0            0.0
#
# [1705 rows x 39 columns]

# %% [markdown]
# As we can see we have 1705 rows but our index reaches only 14 at the end, it means a lot of values in our index are repeated

# %%
matches_rolling.index = range(matches_rolling.shape[0]) # we want unique values for each index

# %%
matches_rolling
# Out:
#            date   time            comp         round  day result   gf   ga  \
# 0    2021-09-11  15:00  Premier League   Matchweek 4  Sat      W    1    0
# 1    2021-09-18  15:00  Premier League   Matchweek 5  Sat      W    1    0
# 2    2021-09-26  16:30  Premier League   Matchweek 6  Sun      W    3    1
# 3    2021-10-02  17:30  Premier League   Matchweek 7  Sat      D    0    0
# 4    2021-10-18  20:00  Premier League   Matchweek 8  Mon      D    2    2
# ...         ...    ...             ...           ...  ...    ...  ...  ...
# 1700 2023-10-21  15:00  Premier League   Matchweek 9  Sat      W  2.0  1.0
# 1701 2023-10-28  17:30  Premier League  Matchweek 10  Sat      D  2.0  2.0
# 1702 2023-11-04  15:00  Premier League  Matchweek 11  Sat      L  1.0  2.0
# 1703 2023-11-11  12:30  Premier League  Matchweek 12  Sat      W  2.0  1.0
# 1704 2023-11-27  20:00  Premier League  Matchweek 13  Mon      L  2.0  3.0
#
#             opponent   xg  ...  target  opp_code  gf_rolling ga_rolling  \
# 0       Norwich City  2.7  ...       1        17    0.000000   3.000000
# 1            Burnley  1.1  ...       1         5    0.333333   2.333333
# 2          Tottenham  1.1  ...       1        21    0.666667   1.666667
# 3           Brighton  0.4  ...       0         4    1.666667   0.333333
# 4     Crystal Palace  1.7  ...       0         7    1.333333   0.333333
# ...              ...  ...  ...     ...       ...         ...        ...
# 1700     Bournemouth  2.4  ...       1         2    1.333333   1.000000
# 1701   Newcastle Utd  0.9  ...       0        16    1.666667   1.000000
# 1702   Sheffield Utd  1.2  ...       0        19    1.666667   1.333333
# 1703       Tottenham  2.1  ...       1        21    1.666667   1.666667
# 1704          Fulham  1.4  ...       0         9    1.666667   1.666667
#
#      sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 0      9.666667    2.333333    14.833333   0.333333         0.0            0.0
# 1     12.333333    3.000000    14.133333   0.333333         0.0            0.0
# 2     14.666667    3.000000    14.800000   0.666667         0.0            0.0
# 3     18.333333    5.333333    18.433333   0.666667         0.0            0.0
# 4     11.000000    4.000000    19.833333   0.666667         0.0            0.0
# ...         ...         ...          ...        ...         ...            ...
# 1700   4.666667    2.333333    11.466667   0.000000         0.0            0.0
# 1701  10.666667    3.666667    14.533333   0.000000         0.0            0.0
# 1702  13.333333    5.333333    16.466667   0.333333         0.0            0.0
# 1703  14.000000    5.333333    16.966667   0.666667         0.0            0.0
# 1704  12.666667    4.333333    17.733333   0.666667         0.0            0.0
#
# [1705 rows x 39 columns]

# %%
train = matches_rolling[matches_rolling['date'] < "2023-01-01"]
test = matches_rolling[matches_rolling['date'] > "2023-01-01"]

# %%
rfc.fit(train[predictors + new_cols], train["target"])
# Out:
# RandomForestClassifier(max_depth=5, max_features=4, min_samples_split=10,
#                        random_state=42)

# %%
preds = rfc.predict(test[predictors + new_cols])

# %%
print("Accuracy:", accuracy_score(test['target'], preds))
print("Precision:", precision_score(test['target'], preds))
print("Recall:", recall_score(test['target'], preds))
# Out:
# Accuracy: 0.6436950146627566
# Precision: 0.5915492957746479
# Recall: 0.31226765799256506

# %% [markdown]
# # Just Testing

# %% [markdown]
# This section was created to test some functions in order to understand them better during the whole process
