# %%
import numpy as np
import pandas as pd

# %%
stats = pd.read_csv('stats.csv')

# %%
del stats['Unnamed: 0']

# %%
stats
# Out:
#        Unnamed: 0          Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0               0      A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  ...
# 1               1     Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  ...
# 2               2  Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  ...
# 3               3   Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9  ...
# 4               4    James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  ...
# ...           ...             ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 15231       15231   Spencer Hawes  PF   28  MIL  54   1  14.8  2.5   5.1  ...
# 15232       15232     Steve Novak  PF   33  MIL   8   0   2.8  0.3   0.9  ...
# 15233       15233  Terrence Jones  PF   25  MIL  54  12  23.5  4.3   9.1  ...
# 15234       15234      Thon Maker   C   19  MIL  57  34   9.9  1.5   3.2  ...
# 15235       15235      Tony Snell  SG   25  MIL  80  80  29.2  3.1   6.8  ...
#
# ...

# %% [markdown]
# At first we should check if we have any missing data

# %%
pd.isnull(stats).sum()
# Out:
# Player        0
# Pos           0
# Age           0
# Tm            0
# G             0
# GS            0
# MP            0
# FG            0
# FGA           0
# FG%          61
# 3P            0
# 3PA           0
# 3P%        2102
# 2P            0
# 2PA           0
# 2P%         105
# eFG%         61
# FT            0
# FTA           0
# FT%         545
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# Year          0
# Pts Won       0
# Pts Max       0
# Share         0
# Team          0
# W             0
# L             0
# W/L%          0
# GB            0
# PS/G          0
# PA/G          0
# SRS           0
# dtype: int64

# %%
stats[pd.isnull(stats["3P%"])][["Player", "3P%"]].head()
# Out:
#              Player  3P%
# 2    Elden Campbell  NaN
# 3     Irving Thomas  NaN
# 18       Jack Haley  NaN
# 20      Keith Owens  NaN
# 30  Benoit Benjamin  NaN

# %%
# 3PA - 3-Point Field Goal Attepmts Per Game
# 3P% - 3-Point Field Goal Percentage
# 3P - 3-Point Field Goals Per Game

# %%
stats = stats.fillna(0)

# %% [markdown]
# Since we're trying to predict mvp votes we must remove the column Share and columns that directly correlate with Share

# %%
stats.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year',
#        'Pts Won', 'Pts Max', 'Share', 'Team', 'W', 'L', 'W/L%', 'GB', 'PS/G',
#        'PA/G', 'SRS'],
#       dtype='object')

# %%
predictors = ["Age", "G", "GS", "MP", "FG", "FGA", 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'W', 'L', 'W/L%',
       'GB', 'PS/G', 'PA/G', 'SRS']

# %%
stats[stats['Year'] == 2023].shape
# Out:
# (539, 41)
